# %%
import aiohttp
import asyncio
import numpy as np
import pickle
import re
import typing as t
import nltk
from nltk.tokenize import word_tokenize
from pymorphy3 import MorphAnalyzer

nltk.download('punkt')
nltk.download('stopwords')

from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\podov\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\podov\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ## Test

# %%
answers = {}

async def fetch(session: aiohttp.ClientSession, url: str, id):
    async with session.get(url) as response:
        await asyncio.sleep((1 + np.random.sample()) * np.random.randint(1, 4))
        answers[id] = await response.json()


async def main():
    semaphore = asyncio.Semaphore(7)
    
    async def sem_task(task):
        async with semaphore:
            return await task
    
    async with aiohttp.ClientSession() as session:
        tasks = []
        ids = np.arange(2)
        np.random.shuffle(ids)
        for id in ids:
            tasks.append(
                sem_task(fetch(session, f'http://127.0.0.1:10005/test/{id}', id))
            )
        await asyncio.gather(*tasks, return_exceptions=False)

# %%
await main()

# %%
answers
# Out:
# {0: {'detail': 'Too Many Requests'}, 1: {'detail': 'Too Many Requests'}}

# %% [markdown]
# ## Not test

# %%
async def sema(n_cor: int, tasks: list) -> None:
    semaphore = asyncio.Semaphore(n_cor)

    async def sem_task(task):
        async with semaphore:
            return await task

    tasks = [sem_task(task) for task in tasks]
    await asyncio.gather(*tasks)

# %%
res = {}

# %%
async def fetch(session: aiohttp.ClientSession, url: str, payload: dict, storage, id):
    async with session.get(url, params=payload) as response:
        await asyncio.sleep(2 * np.random.sample())
        storage[id] = await response.json()

# %%
async with aiohttp.ClientSession() as session:
    tasks = []
    for i in range(20):
        url = f'https://api.hh.ru/vacancies'
        payload = {
            'page': i,
            'per_page': 100,
            'text': 'python',
            'area': 113,  # Россия
            'currency': 'RUR',  # Рубль
            'only_with_salary': 'true',
        }
        tasks.append(fetch(session, url, payload, res, i))
    await sema(7, tasks)

# %%
res.keys()
# Out:
# dict_keys([2, 6, 3, 5, 1, 0, 9, 4, 8, 7, 10, 13, 15, 16, 12, 17, 11, 18, 14, 19])

# %%
for k in res:
    print(res[k]['per_page'], res[k]['pages'], res[k]['page'])
# Out:
# 100 20 2
# 100 20 6
# 100 20 3
# 100 20 5
# 100 20 1
# 100 20 0
# 100 20 9
# 100 20 4
# 100 20 8
# 100 20 7
# 100 20 10
# 100 20 13
# 100 20 15
# 100 20 16
# 100 20 12
# 100 20 17
# 100 20 11
# 100 20 18
# 100 20 14
# 100 20 19

# %% [markdown]
# max = 7 запросов / сек
#
# p.s. и уменьшается под конец?

# %%
ids = {
    vacancy['id']
    for page in res.values()
    for vacancy in page['items']
}
len(ids)
# Out:
# 2000

# %%
ids
# Out:
# {'88979575',
#  '91380259',
#  '90450784',
#  '88698076',
#  '90995033',
#  '90257504',
#  '89140172',
#  '91237704',
#  '89256423',
#  '90337384',
#  '91317061',
#  '89864454',
#  '91416723',
#  '90679259',
#  '90458712',
#  '88950611',
#  '90413558',
#  '90976859',
#  '91244556',
#  '73330479',
#  '85029726',
#  '90743254',
#  '89719599',
#  '91462760',
#  '90037351',
#  '90613306',
#  '90366994',
#  '90259619',
#  '87615622',
#  '90876897',
#  '91385560',
#  '90738704',
#  '87821981',
#  '90936501',
#  '90947151',
#  '86862664',
#  '91039294',
#  '90897567',
#  '91414753',
#  '86185294',
#  '91357598',
#  '90327539',
#  '89709008',
#  '91356259',
#  '91397273',
#  '91251641',
#  '90101512',
#  '88931048',
#  '90437173',
#  '91313480',
#  '90952118',
#  '91451860',
#  '90240682',
#  '91389809',
#  '89438298',
#  '90749548',
#  '90410518',
#  '89719594',
#  '90452145',
#  '90314947',
#  '87918938',
#  '86615827',
#  '86178653',
#  '91221490',
#  '90398559',
#  '87566551',
#  '90536244',
#  '91268022',
#  '90305149',
#  '87647929',
#  '86979717',
#  '91337313',
#  '90338679',
#  '90949948',
#  '90417867',
#  '82893736',
#  '90389129',
#  '91372602',
#  '86258755',
#  '87331516',
#  '88582647',
#  '90666671',
#  '90772203',
#  '91100216',
#  '86280667',
#  '89822909',
#  '90460779',
#  '90241343',
#  '90420320',
#  '90455109',
#  '91341377',
#  '90444838',
#  '90294597',
#  '91459739',
#  '91263648',
#  '91391739',
#  '89262448',
#  '89845685',
#  '90258268',
#  '90743717',
#  '89467825',
#  '90180484',
#  '89617279',
#  '90807342',
#  '90227251',
#  '90855194',
#  '90737399',
#  '90869752',
#  '85774791',
#  '90774119',
#  '91390669',
#  '91143878',
#  '67115536',
#  '90927121',
#  '90682199',
#  '90988636',
#  '90257778',
#  '90859835',
#  '89703807',
#  '91321433',
#  '90309936',
#  '90216751',
#  '91254562',
#  '90700163',
#  '91325901',
#  '91387348',
#  '81590600',
#  '68489073',
#  '89825958',
#  '91003208',
#  '89643699',
#  '86280638',
#  '91074233',
#  '90408454',
#  '89154874',
#  '90500202',
#  '88623848',
#  '91001944',
#  '90444712',
#  '90360024',
#  '91386248',
#  '91454867',
#  '90337385',
#  '91318632',
#  '91306521',
#  '90286261',
#  '90972280',
#  '86528150',
#  '90367911',
#  '85608632',
#  '82310598',
#  '89971282',
#  '89466380',
#  '91296442',
#  '90246638',
#  '91141306',
#  '90394111',
#  '89168575',
#  '91258360',
#  '91172205',
#  '91101332',
#  '91422848',
#  '90285918',
#  '89719576',
#  '91082926',
#  '91249290',
#  '90877456',
#  '90593122',
#  '91369750',
#  '91375040',
#  '91390502',
#  '90476039',
#  '90649310',
#  '91408757',
#  '90407189',
#  '88962145',
#  '91358232',
#  '90994666',
#  '91434851',
#  '91462303',
#  '91241311',
#  '89822929',
#  '91332710',
#  '91291979',
#  '91413513',
#  '69970105',
#  '90529743',
#  '90235532',
#  '91309412',
#  '90634111',
#  '87655408',
#  '91358240',
#  '90211024',
#  '90682201',
#  '90841246',
#  '90276032',
#  '89838003',
#  '90252342',
#  '88265968',
#  '85169840',
#  '87507948',
#  '90618835',
#  '90352318',
#  '90269547',
#  '88450643',
#  '90661218',
#  '91420432',
#  '89464125',
#  '84148599',
#  '89241070',
#  '78050064',
#  '90270712',
#  '90886815',
#  '90262473',
#  '91287393',
#  '85169680',
#  '89996767',
#  '90698345',
#  '91309401',
#  '91101343',
#  '90991889',
#  '90326085',
#  '90717850',
#  '90457713',
#  '90493347',
#  '89759668',
#  '90792642',
#  '87687886',
#  '91418782',
#  '90840443',
#  '89667476',
#  '90688242',
#  '89659414',
#  '91320080',
#  '90782938',
#  '90638059',
#  '88530914',
#  '91140635',
#  '90295046',
#  '90264076',
#  '89233740',
#  '30548119',
#  '79741767',
#  '90938456',
#  '91069072',
#  '91407895',
#  '90323928',
#  '91189961',
#  '86610101',
#  '91450487',
#  '91139448',
#  '91398388',
#  '89957091',
#  '91071205',
#  '90503764',
#  '91425833',
#  '89583504',
#  '89864453',
#  '91415696',
#  '89980286',
#  '90305925',
#  '91386370',
#  '90420317',
#  '90352233',
#  '90944557',
#  '91232398',
#  '90389095',
#  '90846698',
#  '91457942',
#  '91264938',
#  '91264928',
#  '90905958',
#  '90609457',
#  '82945991',
#  '89774325',
#  '90907706',
#  '90981422',
#  '88528970',
#  '91332719',
#  '90474489',
#  '90430102',
#  '71147159',
#  '88899585',
#  '91290100',
#  '91179261',
#  '91323506',
#  '90237331',
#  '91290321',
#  '90532900',
#  '90821364',
#  '90752568',
#  '86293851',
#  '88464398',
#  '87854357',
#  '88011644',
#  '90029143',
#  '84959738',
#  '89193400',
#  '90903905',
#  '91329827',
#  '90762017',
#  '89997213',
#  '88569194',
#  '91394488',
#  '90282309',
#  '90994912',
#  '84940364',
#  '91095558',
#  '88239956',
#  '90435913',
#  '89679433',
#  '90248101',
#  '86631661',
#  '91412972',
#  '90850468',
#  '90687777',
#  '91214258',
#  '89941946',
#  '90997675',
#  '90994505',
#  '90798475',
#  '89136806',
#  '91341282',
#  '91044806',
#  '90712821',
#  '90538646',
#  '89722909',
#  '91309421',
#  '90687617',
#  '91411584',
#  '90898637',
#  '69962567',
#  '89486095',
#  '90732824',
#  '90640575',
#  '90731839',
#  '88704458',
#  '91255748',
#  '89726901',
#  '88262986',
#  '89719586',
#  '89687776',
#  '90894503',
#  '90761334',
#  '91408739',
#  '91347299',
#  '90639439',
#  '90963419',
#  '89997395',
#  '87822966',
#  '89510607',
#  '91321832',
#  '90339355',
#  '91153344',
#  '91304537',
#  '91407141',
#  '76431704',
#  '91164283',
#  '89851745',
#  '86880519',
#  '89438818',
#  '91372646',
#  '91140567',
#  '90988769',
#  '90520527',
#  '91458816',
#  '88591441',
#  '91365752',
#  '90674876',
#  '91033304',
#  '91306522',
#  '90880622',
#  '90679668',
#  '91371529',
#  '91071291',
#  '86979719',
#  '91388360',
#  '91329743',
#  '90211031',
#  '90721319',
#  '89301263',
#  '86862689',
#  '90691719',
#  '90944365',
#  '89740121',
#  '91366636',
#  '89367333',
#  '90798524',
#  '90867249',
#  '91255929',
#  '84854267',
#  '87819753',
#  '91254188',
#  '91234354',
#  '90903104',
#  '90456805',
#  '91224284',
#  '89719596',
#  '89719593',
#  '90949202',
#  '90665603',
#  '90789679',
#  '89997699',
#  '90338263',
#  '90430162',
#  '91309462',
#  '90659186',
#  '91089772',
#  '91410316',
#  '90675252',
#  '84484404',
#  '91321812',
#  '90742951',
#  '90944369',
#  '90977417',
#  '87218573',
#  '90810627',
#  '90512353',
#  '88528864',
#  '90906499',
#  '87167145',
#  '86227389',
#  '85975102',
#  '91457943',
#  '90241370',
#  '90541330',
#  '90981999',
#  '91165220',
#  '90355605',
#  '89942587',
#  '89062092',
#  '91321936',
#  '91341389',
#  '90420316',
#  '90900361',
#  '91002011',
#  '90574666',
#  '90684113',
#  '83740435',
#  '87643118',
#  '87827282',
#  '89719598',
#  '91364065',
#  '88736516',
#  '86682772',
#  '89492263',
#  '91317222',
#  '90788458',
#  '80161074',
#  '90641147',
#  '91143426',
#  '91359356',
#  '85939909',
#  '91309379',
#  '90767748',
#  '88508612',
#  '91374623',
#  '91049961',
#  '90625952',
#  '84247046',
#  '85975544',
#  '90772184',
#  '90625953',
#  '82138937',
#  '89182221',
#  '86979718',
#  '90352535',
#  '83701313',
#  '86667054',
#  '90409592',
#  '91332221',
#  '90975825',
#  '90342228',
#  '91245775',
#  '86631667',
#  '89132087',
#  '90420315',
#  '90865663',
#  '89203447',
#  '90995252',
#  '90696598',
#  '88736659',
#  '91068125',
#  '90094553',
#  '90877106',
#  '91037373',
#  '90270869',
#  '90630548',
#  '89713673',
#  '91150244',
#  '90660474',
#  '88058766',
#  '91309458',
#  '88930570',
#  '89012851',
#  '90615616',
#  '76960599',
#  '78050090',
#  '88451413',
#  '91108508',
#  '90909962',
#  '90420318',
#  '90808056',
#  '90294057',
#  '90653218',
#  '89419707',
#  '90267840',
#  '89719600',
#  '91139867',
#  '90952117',
#  '72862686',
#  '91189575',
#  '91260437',
#  '90359299',
#  '91388444',
#  '90914139',
#  '89719597',
#  '90515547',
#  '91378810',
#  '91168618',
#  '91396185',
#  '90747986',
#  '90520530',
#  '90438300',
#  '90739949',
#  '91427541',
#  '91347303',
#  '90298399',
#  '91303671',
#  '90231606',
#  '86196022',
#  '90352955',
#  '90618371',
#  '91097316',
#  '91409125',
#  '91003193',
#  '90380232',
#  '86631664',
#  '91308813',
#  '90727614',
#  '90501919',
#  '91264933',
#  '86089234',
#  '90915533',
#  '91305318',
#  '90345123',
#  '91366281',
#  '90883533',
#  '90677428',
#  '88366180',
#  '90290636',
#  '91315141',
#  '90353749',
#  '91043997',
#  '87168831',
#  '88646622',
#  '91147267',
#  '91127586',
#  '89635755',
#  '91286645',
#  '90787049',
#  '82982085',
#  '91457941',
#  '91187504',
#  '91390102',
#  '89991510',
#  '90986757',
#  '90610562',
#  '89213966',
#  '91457944',
#  '91280206',
#  '90625947',
#  '91264927',
#  '86897651',
#  '90840092',
#  '90767747',
#  '90288317',
#  '91246663',
#  '90222479',
#  '89509779',
#  '90777043',
#  '91247158',
#  '90431656',
#  '90614795',
#  '90205241',
#  '91122487',
#  '91117856',
#  '90019715',
#  '90642542',
#  '90456436',
#  '91277157',
#  '90160059',
#  '90414053',
#  '91361513',
#  '91435929',
#  '90725699',
#  '89787712',
#  '90306800',
#  '91252007',
#  '87448845',
#  '90988944',
#  '89492262',
#  '90610910',
#  '90898732',
#  '91251842',
#  '91332228',
#  '89273454',
#  '90625949',
#  '90837912',
#  '91147781',
#  '90538647',
#  '91359573',
#  '90885622',
#  '88873656',
#  '91217629',
#  '91053778',
#  '86979720',
#  '90830492',
#  '90903904',
#  '90337379',
#  '90515098',
#  '91264924',
#  '90473157',
#  '91286967',
#  '90252765',
#  '91445541',
#  '90327415',
#  '90411949',
#  '90438585',
#  '91416341',
#  '90274291',
#  '91350244',
#  '91439308',
#  '90029139',
#  '90915415',
#  '91273774',
#  '90597233',
#  '91321525',
#  '90742953',
#  '90863215',
#  '91159597',
#  '91178964',
#  '90240683',
#  '91454118',
#  '89719589',
#  '90928727',
#  '90134566',
#  '91259199',
#  '87619791',
#  '91238732',
#  '90736506',
#  '88918605',
#  '90227423',
#  '89358110',
#  '90344153',
#  '90802206',
#  '90680237',
#  '91077945',
#  '90267524',
#  '91340252',
#  '91324840',
#  '78412670',
#  '89092030',
#  '91242897',
#  '90673606',
#  '88737058',
#  '85975111',
#  '90568268',
#  '91264930',
#  '91314072',
#  '91026652',
#  '91406241',
#  '91123888',
#  '91435486',
#  '89739162',
#  '89165728',
#  '90257856',
#  '84399422',
#  '90776928',
#  '91187524',
#  '91267470',
#  '90612336',
#  '90901232',
#  '90641703',
#  '88963319',
#  '91297224',
#  '90456435',
#  '91074300',
#  '79004413',
#  '90962329',
#  '90944368',
#  '90183629',
#  '90819922',
#  '88546860',
#  '90615615',
#  '90701739',
#  '77911825',
#  '88306269',
#  '90735127',
#  '90253388',
#  '89655902',
#  '91372669',
#  '90876814',
#  '77070621',
#  '90740382',
#  '90540586',
#  '91121098',
#  '90378560',
#  '90770850',
#  '90615531',
#  '90445161',
#  '90653217',
#  '91378798',
#  '90460851',
#  '90802746',
#  '90417932',
#  '91070779',
#  '90944370',
#  '86904577',
#  '88182259',
#  '90646885',
#  '90749960',
#  '91307016',
#  '91090660',
#  '91168226',
#  '90799472',
#  '80794263',
#  '91237789',
#  '90726577',
#  '91256990',
#  '91140735',
#  '91091181',
#  '91412996',
#  '90360023',
#  '90382584',
#  '84888866',
#  '89719577',
#  '90402445',
#  '90792191',
#  '91297374',
#  '89761049',
#  '86544541',
#  '89636205',
#  '89643676',
#  '91335751',
#  '89143289',
#  '87990330',
#  '90944371',
#  '88684240',
#  '90360021',
#  '89272563',
#  '90255577',
#  '90683419',
#  '90444887',
#  '91458405',
#  '91307854',
#  '90337381',
#  '91354946',
#  '89765413',
#  '90654616',
#  '90507692',
#  '89833089',
#  '91270975',
#  '90287646',
#  '90279269',
#  '90730547',
#  '90413333',
#  '90814475',
#  '89747841',
#  '91024612',
#  '90371069',
#  '90823367',
#  '87394962',
#  '90515097',
#  '91264925',
#  '90721437',
#  '90860121',
#  '90747442',
#  '90398375',
#  '90903581',
#  '90786227',
#  '90944099',
#  '89161544',
#  '90947023',
#  '89659495',
#  '89595866',
#  '90630324',
#  '90660231',
#  '90337374',
#  '89708690',
#  '90697373',
#  '89536164',
#  '90777119',
#  '89692025',
#  '90468486',
#  '43425529',
#  '90885437',
#  '91307482',
#  '91321935',
#  '91304719',
#  '89682651',
#  '90791182',
#  '89244147',
#  '90886143',
#  '90211028',
#  '90356190',
#  '90337366',
#  '90743030',
#  '91217831',
#  '90275731',
#  '90874768',
#  '90886648',
#  '90649312',
#  '89517110',
#  '91151380',
#  '90427629',
#  '91182452',
#  '90688672',
#  '89358111',
#  '90520528',
#  '88930678',
#  '87988955',
#  '91292655',
#  '90544984',
#  '90004309',
#  '91435487',
#  '75827933',
#  '91280604',
#  '91260247',
#  '90349057',
#  '89561599',
#  '91439404',
#  '90349041',
#  '90334440',
#  '91455798',
#  '89719583',
#  '91139447',
#  '90645178',
#  '91341366',
#  '91362352',
#  '91445537',
#  '90505963',
#  '91082069',
#  '89719578',
#  '82391131',
#  '91236542',
#  '89753481',
#  '90970365',
#  '90805712',
#  '89573653',
#  '90841383',
#  '90211030',
#  '90897571',
#  '90720957',
#  '91440806',
#  '90792829',
#  '90202332',
#  '90460755',
#  '91163215',
#  '90988308',
#  '91448146',
#  '90646978',
#  '91375691',
#  '90815758',
#  '86631663',
#  '91126871',
#  '91273172',
#  '90332187',
#  '87493266',
#  '90410562',
#  '90873134',
#  '90460747',
#  '91109531',
#  '88432488',
#  '89968859',
#  '90615618',
#  '91301920',
#  '90875816',
#  '90335474',
#  '90799138',
#  '82742802',
#  '90332539',
#  '89109374',
#  '91187726',
#  '90302826',
#  '91264932',
#  '90599236',
#  '87249443',
#  '89748615',
#  '91123793',
#  '91390745',
#  '91074600',
#  '89719587',
#  '90506673',
#  '90647610',
#  '91121451',
#  '90288316',
#  '88865711',
#  '89610184',
#  '91325271',
#  '86610089',
#  '82829228',
#  '90992437',
#  '91435488',
#  '91101019',
#  '91359354',
#  '89742896',
#  '90449602',
#  '90682200',
#  '90673695',
#  '88566881',
#  '91094400',
#  '91396043',
#  '91255861',
#  '90342229',
#  '90328327',
#  '90267535',
#  '91350040',
#  '91326060',
#  '88569097',
#  '91039295',
#  '90654575',
#  '91365169',
#  '88465302',
#  '90445291',
#  '72687495',
#  '90438142',
#  '84959845',
#  '90984922',
#  '90653222',
#  '90745859',
#  '89038853',
#  '89977412',
#  '91343218',
#  '91366258',
#  '90314915',
#  '90385551',
#  '90240673',
#  '91166631',
#  '87769575',
#  '91462156',
#  '88998474',
#  '86173321',
#  '91110476',
#  '89961340',
#  '90897565',
#  '90310055',
#  '90906017',
#  '90897570',
#  '91221078',
#  '90333333',
#  '82837539',
#  '90288920',
#  '91193332',
#  '90505566',
#  '89424767',
#  '90213806',
#  '88467064',
#  '90029140',
#  '87796748',
#  '86574703',
#  '91141609',
#  '88940461',
#  '89516119',
#  '91147735',
#  '91266083',
#  '91353717',
#  '91437840',
#  '89447092',
#  '82632615',
#  '90865057',
#  '91415316',
#  '87935354',
#  '91110256',
#  '90283220',
#  '90800117',
#  '91195757',
#  '90237644',
#  '91309572',
#  '90616288',
#  '91417579',
#  '91442549',
#  '91236581',
#  '89975544',
#  '90653220',
#  '90545458',
#  '90643487',
#  '91251681',
#  '91368235',
#  '89204786',
#  '91334356',
#  '90804750',
#  '91293199',
#  '91108294',
#  '90079470',
#  '90906874',
#  '90798946',
#  '90913717',
#  '91363656',
#  '90841510',
#  ...}

# %%
vacancies = {}

# %%
ids_to_fetch = ids.copy()
async with aiohttp.ClientSession() as session:
    while len(ids_to_fetch):
        ok_ids = {k for k, v in vacancies.items() if 'id' in v.keys()}
        ids_to_fetch -= ok_ids
        print(f'Ok is {len(ok_ids)}.\t To fetch is {len(ids_to_fetch)}')

        tasks = []
        for id in ids_to_fetch:
            url = f'https://api.hh.ru/vacancies/{id}'
            payload = {}
            tasks.append(fetch(session, url, payload, vacancies, id))
        await sema(7, tasks)
# Out:
# Ok is 0.	 To fetch is 2000
# Ok is 635.	 To fetch is 1365
# Ok is 968.	 To fetch is 1032
# Ok is 1192.	 To fetch is 808
# Ok is 1384.	 To fetch is 616
# Ok is 1510.	 To fetch is 490
# Ok is 1654.	 To fetch is 346
# Ok is 1724.	 To fetch is 276
# Ok is 1770.	 To fetch is 230
# Ok is 1812.	 To fetch is 188
# Ok is 1879.	 To fetch is 121
# Ok is 1879.	 To fetch is 121
# Ok is 1925.	 To fetch is 75
# Ok is 1954.	 To fetch is 46
# Ok is 1954.	 To fetch is 46
# Ok is 1954.	 To fetch is 46
# Ok is 1958.	 To fetch is 42
# Ok is 1973.	 To fetch is 27
# Ok is 1999.	 To fetch is 1
# Ok is 2000.	 To fetch is 0

# %% [markdown]
# 5 + 7 + 4 + 2 = <18
#
# 23m

# %%
list(vacancies.values())[0]
# Out:
# {'id': '88979575',
#  'premium': False,
#  'billing_type': {'id': 'standard', 'name': 'Стандарт'},
#  'relations': [],
#  'name': 'Analyst (уклон в Bi)',
#  'insider_interview': None,
#  'response_letter_required': False,
#  'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#  'salary': {'from': 2000, 'to': None, 'currency': 'USD', 'gross': False},
#  'type': {'id': 'open', 'name': 'Открытая'},
#  'address': None,
#  'allow_messages': True,
#  'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#  'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#  'employment': {'id': 'full', 'name': 'Полная занятость'},
#  'department': None,
#  'contacts': None,
#  'description': '<p><strong>Finstar Financial Group</strong> – крупный международный холдинг, в который входят компании по всему миру. Основной бизнес – онлайн кредитование до банковского сегмента. Мы – амбициозная, дружная и активная команда, которая работает над современным финансовым сервисом. Сейчас мы фокусируемся на проектах для стран Юго-Восточной Азии. В связи с динамичным развитием мы ищем в команду нового <strong>BI analyst </strong>с релокацией во Вьетнам.</p> <p><strong>Чем предстоит заниматься:</strong></p> <ul> <li>Взаимодействия с бизнес-заказчиками по вопросам отчетности, анализ требований;</li> <li>Разработка витрин данных, участие в проектировании и развитии архитектуры DWH;</li> <li>Разработка отчетности в Power BI;</li> <li>Автоматизация бизнес-процессов;</li> <li>Написание различной сложности SQL скриптов, оптимизация SQL скриптов;</li> <li>Возможно использование Python в целях автоматизации и организации ETL процессов.</li> </ul> <p><strong>Тебе подойдет вакансия, если у тебя есть:</strong></p> <ul> <li>Математическое/техническое высшее образование;</li> <li>Опыт работы с Power BI или иным BI инструментом;</li> <li>Понимание, чем отличается оптимальный SQL запрос от неоптимального и опыт разработки сложных SQL скриптов, процедур;</li> <li>Разговорный английский язык (B2 и выше);</li> <li>Готовность к релокации в г. Хошимин, Вьетнам.</li> </ul> <p><strong>Мы предлагаем:</strong></p> <ul> <li>Прозрачную систему мотивации (оклад + ежегодные бонусы);</li> <li>Отсутствие бюрократии, высокая степень свободы. Решения принимаются очень быстро;</li> <li>Полный релокационный пакет (визы, билеты и страховки для сотрудника и семьи, оплата отеля, оформление всех документов на стороне компании) - релокация во Вьетнам;</li> <li>Бесплатные обучения;</li> <li>Тимбилдинги в странах Азии (мы уже были на Филиппинах, Фукуоке, Бали, а следующий тимбилдинг планируем на Пхукете).</li> </ul>',
#  'branded_description': None,
#  'vacancy_constructor_template': None,
#  'key_skills': [{'name': 'SQL'},
#   {'name': 'MS SQL Server'},
#   {'name': 'Data Analysis'},
#   {'name': 'MS SQL'},
#   {'name': 'Business Analysis'},
#   {'name': 'Power BI'}],
#  'accept_handicapped': False,
#  'accept_kids': False,
#  'archived': False,
#  'response_url': None,
#  'specializations': [],
#  'professional_roles': [{'id': '96', 'name': 'Программист, разработчик'}],
#  'code': None,
#  'hidden': False,
#  'quick_responses_allowed': False,
#  'driver_license_types': [],
#  'accept_incomplete_resumes': False,
#  'employer': {'id': '180028',
#   'name': 'Finstar Financial Group',
#   'url': 'https://api.hh.ru/employers/180028',
#   'alternate_url': 'https://hh.ru/employer/180028',
#   'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/685633.jpg',
#    '240': 'https://hhcdn.ru/employer-logo/3183665.jpeg',
#    '90': 'https://hhcdn.ru/employer-logo/3183664.jpeg'},
#   'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=180028',
#   'accredited_it_employer': False,
#   'trusted': True},
#  'published_at': '2024-01-09T11:46:34+0300',
#  'created_at': '2024-01-09T11:46:34+0300',
#  'initial_created_at': '2023-11-02T09:58:13+0300',
#  'negotiations_url': None,
#  'suitable_resumes_url': None,
#  'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=88979575',
#  'has_test': False,
#  'test': None,
#  'alternate_url': 'https://hh.ru/vacancy/88979575',
#  'working_days': [],
#  'working_time_intervals': [],
#  'working_time_modes': [],
#  'accept_temporary': False,
#  'languages': [{'id': 'eng',
#    'name': 'Английский',
#    'level': {'id': 'b1', 'name': 'B1 — Средний'}}]}

# %%
all(x['description'] for x in vacancies.values())
# Out:
# True

# %%
path = '../storage/vacancies_2k__11_01_24.pkl'

# with open(path, 'wb') as f:
#     pickle.dump(vacancies, f)

# with open(path, 'rb') as f:
#     vacancies = pickle.load(f)

# %%
import pandas as pd

# %%
{x['salary']['currency'] for x in vacancies.values()}
# Out:
# {'EUR', 'RUR', 'USD'}

# %%
def convert_to_rub(x: float, currency: str) -> float:
    # Курс на 11.01.2024
    match currency:
        case 'RUR':
            return x
        case 'USD':
            return x * 89.39
        case 'EUR':
            return x * 97.87


data = [
    {
        'id': x['id'],
        'description': x['description'],
        'salary': convert_to_rub(
            x=np.mean([value for value in (x['salary']['from'], x['salary']['to']) if value is not None]),
            currency=x['salary']['currency'],
        ),
    }
    for x in vacancies.values()
]

df = pd.DataFrame(data=data, columns=['id', 'description', 'salary'])
df.head()
# Out:
#          id                                        description    salary
# 0  88979575  <p><strong>Finstar Financial Group</strong> – ...  178780.0
# 1  91380259  <p><strong>Кто мы?</strong></p> <p><strong>AdG...  150000.0
# 2  90633183  <p><strong>Чем предстоит заниматься:</strong><...  250000.0
# 3  91216567  <p>Компания Brooma является аккредитованной IT...  120000.0
# 4  91001613  <p>Для основного продукта <strong>Wallcraft</s...  300000.0

# %%
df['salary'].describe()
# Out:
# count       2000.000000
# mean      165038.528750
# std       107103.085843
# min        15000.000000
# 25%        87000.000000
# 50%       150000.000000
# 75%       210000.000000
# max      1000000.000000
# Name: salary, dtype: float64

# %%
corpus = df['description'].values.tolist()

# %%
corpus[:5]
# Out:
# ['<p><strong>Finstar Financial Group</strong> – крупный международный холдинг, в который входят компании по всему миру. Основной бизнес – онлайн кредитование до банковского сегмента. Мы – амбициозная, дружная и активная команда, которая работает над современным финансовым сервисом. Сейчас мы фокусируемся на проектах для стран Юго-Восточной Азии. В связи с динамичным развитием мы ищем в команду нового <strong>BI analyst </strong>с релокацией во Вьетнам.</p> <p><strong>Чем предстоит заниматься:</strong></p> <ul> <li>Взаимодействия с бизнес-заказчиками по вопросам отчетности, анализ требований;</li> <li>Разработка витрин данных, участие в проектировании и развитии архитектуры DWH;</li> <li>Разработка отчетности в Power BI;</li> <li>Автоматизация бизнес-процессов;</li> <li>Написание различной сложности SQL скриптов, оптимизация SQL скриптов;</li> <li>Возможно использование Python в целях автоматизации и организации ETL процессов.</li> </ul> <p><strong>Тебе подойдет вакансия, если у тебя есть:</strong></p> <ul> <li>Математическое/техническое высшее образование;</li> <li>Опыт работы с Power BI или иным BI инструментом;</li> <li>Понимание, чем отличается оптимальный SQL запрос от неоптимального и опыт разработки сложных SQL скриптов, процедур;</li> <li>Разговорный английский язык (B2 и выше);</li> <li>Готовность к релокации в г. Хошимин, Вьетнам.</li> </ul> <p><strong>Мы предлагаем:</strong></p> <ul> <li>Прозрачную систему мотивации (оклад + ежегодные бонусы);</li> <li>Отсутствие бюрократии, высокая степень свободы. Решения принимаются очень быстро;</li> <li>Полный релокационный пакет (визы, билеты и страховки для сотрудника и семьи, оплата отеля, оформление всех документов на стороне компании) - релокация во Вьетнам;</li> <li>Бесплатные обучения;</li> <li>Тимбилдинги в странах Азии (мы уже были на Филиппинах, Фукуоке, Бали, а следующий тимбилдинг планируем на Пхукете).</li> </ul>',
#  '<p><strong>Кто мы?</strong></p> <p><strong>AdGo — это молодая, динамично развивающаяся компания, объединяющая профессионалов и новичков рынка российской и международной интернет-рекламы. Мы работаем по всему миру, применяя лучшие практики. Благодаря нашему энтузиазму и сплоченной команде за 8 лет мы достигли отличных результатов</strong>. <strong>Наша философия - это бережное и внимательное отношение к людям. Здесь вы никогда не останетесь один на один с трудностями, а ваши самые невероятные и креативные идеи будут на вес золота.</strong></p> <p><strong>Наша компания - это простор для мыслей, творчества, самореализации и роста.</strong></p> <p><strong>Вам будет комфортно с нами - если вы придерживаетесь похожих ценностей, питаете страсть к работе, цените любую возможность стать лучше и опытней.</strong></p> <p><strong>Мы - командные игроки, которые любят рисковать, принимать трудные решения и ставить поистине сложные задачи.</strong></p> <p><strong>Кого мы ищем?</strong><br /><strong>Единомышленников! Талантливых людей, желающих найти не просто новую работу, но и неограниченные возможности для профессионального роста и личного развития.</strong></p> <p><strong>Обязанности:</strong></p> <ul> <li> <p>обслуживание виртуальных и железных серверов, от заказа до сдачи</p> </li> <li> <p>настройка, инвентаризация/документирование серверов и сервисов</p> </li> <li> <p>диагностика и решение железных и сетевых проблем посредством общения с саппортом хостинг-провайдеров</p> </li> <li> <p>первая линия саппорта для различных команд разработки и коллег из других отделов</p> </li> <li> <p>настройка мониторинга, реагирование на оповещения системы мониторинга</p> </li> <li> <p>настройка пайплайнов, настройка деплоя приложений</p> </li> <li> <p>создание и развертывание из бэкапов ОС, баз данных, других сервисов</p> </li> </ul> <strong>Требования:</strong> <p> </p> <ul> <li> <p>опыт администрирования RHEL-based OS</p> </li> <li> <p>опыт администрирования linux приложений (веб-серверы, базы данных, почтовые серверы, системы мониторинга)</p> </li> <li> <p>уверенное знание TCP/IP</p> </li> <li> <p>базовые знания systemd, docker, kubernetes, gitlab-ci, ansible</p> </li> <li> <p>базовые знания bash/python/golang</p> </li> <li> <p>аналитические навыки для предотвращения и устранения неисправностей систем</p> </li> </ul> <p><strong>Будет плюсом:</strong></p> <ul> <li> <p>работа с CAPSMAN mikrotik</p> </li> <li> <p>опыт работы с jupyter-hub/notebook</p> </li> <li> <p>умения в настройке различных типов vpn, proxy</p> </li> </ul> <p><strong>Наш стек:</strong></p> <ul> <li> <p>clickhouse + zookeeper, mysql, postgresql, vertica</p> </li> <li> <p>aerospike, memcached, redis</p> </li> <li> <p>php, js, golang</p> </li> <li> <p>nginx</p> </li> <li> <p>dovecot, postfix, roundcube</p> </li> <li> <p>gitlab, docker, kubernetes</p> </li> <li> <p>grafana, influxdb, kapacitor, ELK stack</p> </li> <li> <p>openvpn, wireguard, ikev2</p> </li> </ul> <strong>Условия:</strong> <ul> <li> <p>Работа удалённо, но с периодическими посещениями офиса в СПб ( 2-3 раза в месяц);</p> </li> <li> <p>Рабочий день длится всего 8 часов, и вы можете выбрать когда начать свой рабочий день (с 9:00 до 11:00). Это значит, что у вас есть больше свободного времени для личных дел и хобби!</p> </li> <li> <p>У вас будет доступ к нашей шикарной корпоративной страховке. Забота о вашем здоровье - это наш приоритет!</p> </li> <li> <p>Мы даем вам возможность иметь один дополнительный выходной день в месяц, чтобы полностью расслабиться, забыть о работе и заниматься тем, что вам действительно нравится!</p> </li> <li> <p>Каждый год мы устраиваем драйвовые корпоративные мероприятия, чтобы вы могли насладиться развлечениями и почувствовать командный дух. И это не просто тимбилдинг недалеко от города с эстафетой. Это паром в Стамбуле, яркое празднование Нового Года в Будапеште, уютные улочки старого города Таллина с глинтвейном в руках, подьем в горы в Архызе, или создание плота (как в детстве) в Казани!< ...
#  '<p><strong>Чем предстоит заниматься:</strong></p> <ul> <li>Поддержкой работоспособности информационных систем и приложений собственной разработки в периметре своего отдела: Kafka, Yoda-платформа Gravitee, Jira, Confluence, Prometheus, Keycloak, Grafana, NAVTEQ, центральные репозитории;</li> <li>Управление командой в целях реализации задач группы;</li> <li>Решением инцидентов и устранением сбоев, возникающих в информационных системах, приложениях, ИТ-платформах и модулях в рамках зоны своей ответственности; контролем поступающих обращений и заявок;</li> <li>Планированием регламентных работ по обновлению версий ПО, по изменению текущих настроек и конфигураций, по установке информационных систем, приложений, ИТ-платформ, модулей на нового сервера, а также по настройке новых программных продуктов, утвержденных архитекторами отдела;</li> <li> <p>Анализом входящей документации для проектирования и разработки ИТ-решений, выработкой рекомендаций по улучшению документации по ИТ-процессам;</p> </li> <li> <p>Внедрением процесса, обеспечивающего поддержку и предоставление ИТ-сервисов (ITSM) в рамках функции группы;</p> </li> <li> <p>Формированием и поддержание в актуальном состоянии базы знаний в зоне своей ответственности (Confluence).</p> </li> </ul> <p><br /><strong>Пожелания к кандидату:</strong></p> <ul> <li>Аналогичный опыт от 3-х лет;</li> <li>Опыт управления командой от 10-ти человек;</li> <li>Знание Linux, Windows, Kafka, Talend, Gravitee, языков программирования Java и Python. Широкий кругозор по технологиям интеграции. Контейнеризация Docker, оркестрация Docker (Swarm, Kubernetes), мониторинг (Graphana, Kibana);</li> <li> <p>Продвинутый английский язык будет преимуществом.</p> <p> </p> </li> </ul> <p><strong>Мы предлагаем:</strong></p> <ul> <li> <p>Оформление в аккредитованную IT-компанию;</p> </li> <li> <p>Гибридный график и комфортный офис;</p> </li> <li> <p>Расширенный пакет ДМС со стоматологией, выездом врачей на дом. К ДМС можно подключать детей через 1 год работы;</p> </li> <li> <p>Внутрикорпоративное обучение;</p> </li> <li> <p>Скидки в наших магазинах и льготные условия от партнеров;</p> </li> <li> <p>Бесплатная парковка;</p> </li> <li> <p>Корпоративная столовая;</p> </li> <li> <p>Премии по результатам работы;</p> </li> <li> <p>Возможность влиять на процессы, принимать решения и реализовывать свои идеи;</p> </li> <li> <p>Участие в проектах федерального масштаба;</p> </li> <li> <p>Работайте вместе с друзьями и получайте премию за каждого трудоустроенного друга!</p> </li> </ul>',
#  '<p>Компания Brooma является аккредитованной IT-компанией, специализирующейся на разработке инновационного продукта Jeffit. Наша основная цель - предоставить передовые IT-решения, которые помогут юридическим фирмам и юридическим департаментам эффективно управлять своими процессами.</p> <p>Мы гордимся нашими клиентами, среди которых такие крупные компании, как Siemens, Unilever, Мвидео, Сибур, НЛМК и Лукоил.</p> <p>У нас два офиса. Головной офис расположен в Москве, где работают наши Product Owner&#39;ы, бизнес-аналитики и UX-специалисты. В нашем центре разработки в Новосибирске мы сосредоточены на backend и frontend разработке, а также на работе QA и DevOps. Мы постоянно стремимся к совершенству и привлекаем лучших специалистов в нашу команду, чтобы обеспечить высокое качество наших продуктов и удовлетворение потребностей наших клиентов.</p> <p>В настоящее время <strong>мы ищем опытного инженера DevOps/Системного администратора (SRE)</strong>, ответственного за сопровождение наших облачных продуктов и систем на стороне заказчика.<strong> Мы ищем кандидата, который обладает опытом работы с администрированием Ubuntu/CentOS, написанием скриптов на bash/python, работой с системами виртуализации и облачными IaaS-сервисами, а также опытом развертывания и обслуживания веб-серверов.</strong></p> <p><strong>Основные требования:</strong></p> <ul> <li>Опыт администрирования Ubuntu/CentOS.</li> <li>Опыт написания скриптов на bash/python.</li> <li>Опыт работы с системами виртуализации и облачными IaaS-сервисами.</li> <li>Опыт развертывания и обслуживания веб-серверов.</li> </ul> <p><strong>Желательные навыки:</strong></p> <ul> <li>Знакомство со стеком технологий, включающим tomcat/postgresql/java EE 8(spring)/haproxy/nginx/activeMQ/redis.</li> <li>Готовность работать с Windows Server и разными дистрибутивами Linux.</li> <li>Знакомство с системами управления конфигурациями (например, Ansible).</li> </ul> <p><strong>Основные задачи:</strong></p> <ul> <li>Сопровождение наших облачных продуктов и систем на стороне заказчика, включая мониторинг с использованием Zabbix.</li> <li>Совместная работа с разработчиками для поиска и устранения проблем, а также разбора инцидентов.</li> <li>Деплой и масштабирование/балансировка нагрузки.</li> <li>Определение требований к серверному оборудованию.</li> <li>Поддержка и доработка скриптов автоматизации и систем CI/CD на базе Jenkins и GitLab репозитория.</li> <li>Подготовка системного окружения для разработки.</li> <li>Участие в формировании технических требований к компонентам и нагрузочном тестировании.</li> </ul> <p><strong>Мы предлагаем:</strong></p> <ul> <li>Работу в аккредитованной IT-компании над передовым продуктом в области LegalTech.</li> <li>ДМС после успешного завершения испытательного срока.</li> <li>Офисный, гибридный или полностью удаленный формат работы.</li> <li>Уникальную возможность принимать решения в процессе реализации технических задач и влиять на развитие проектов и процессы в компании.</li> <li>Атмосферу взаимного обмена знаниями и поддержки между командами.</li> <li>Регулярные перфоманс ревью, установление персональных целей и разработка плана для вашего личного развития. Мы ценим рост наших сотрудников и предоставляем инструменты для их профессионального развития.</li> <li>Отсутствие бюрократии. Мы создаем условия, в которых вы можете сосредоточиться на своих задачах, минимизируя лишние согласования.</li> </ul> <p>Присоединяйтесь к нам, и вы получите возможность работать с передовыми технологиями, развивать свои навыки и внести значимый вклад в индустрию LegalTech!</p>',
#  '<p>Для основного продукта <strong>Wallcraft</strong> (более 200 млн. загрузок, 6 млн активных пользователей в месяц) ищем <strong>Senior/Team lead Machine Learning Engineer</strong>, который сможет усилить нашу команду.</p> <p><strong>Тебе предстоит:</strong></p> <ul> <li>заниматься исследованием и имплементацией различных алгоритмов в рекомендательной системе;</li> <li>проводить эксперименты и оптимизировать SOTA генеративных моделей;</li> <li>организацией эффективной работы ML отдела;</li> <li>адаптацией и совершенствованием существующих алгоритмов.</li> </ul> <p>Ипользуемый стэк: Python, Pytorch, BigQuery, Clickhouse, Postgres</p> <p><strong>Мы рассчитываем, что у тебя есть опыт и знания для этой позиции. А именно:</strong></p> <ul> <li>5+ лет опыта в роли Machine Learning Engineer (желателен опыт в мобильных приложениях);</li> <li>знание основ статистики;</li> <li>опыт и понимание классических ML-алгоритмов и DL;</li> <li>опыт реализации и применения моделей машинного обучения в продакшене;</li> <li>уверенное владение Python (numpy, pandas, scipy, pytorch, sklearn).</li> </ul> <p><strong>Мы предлагаем:</strong></p> <ul> <li>\u200b\u200b\u200b\u200b\u200b\u200b\u200bполную занятость с гибким началом рабочего дня;</li> <li>высокую заработную плату, бонусы за результат;</li> <li>офис в центре Пензы с панорамным видом/удаленную работу;</li> <li>предоставление всей необходимой для работы техники;</li> <li> <p>возглавить отдел ML (вы будете работать один в начале, далее возможен найм вам помощника при необходимости, которого вы выберете сами).</p> </li> </ul>']

# %%
def apply_re(pattern: str, reply_on: str, corpus: t.Sequence[str]) -> t.MutableSequence[str]:
    return list(map(lambda x: re.sub(pattern, reply_on, x), corpus))

# %%
corpus = apply_re('(<[^>]+>|\s)', ' ', corpus)
corpus = apply_re('[^{а-яА-Яa-zA-Z0-9}]', ' ', corpus)
corpus = apply_re('\s+', ' ', corpus)

corpus[:10]
# Out:
# [' Finstar Financial Group крупный международный холдинг в который входят компании по всему миру Основной бизнес онлайн кредитование до банковского сегмента Мы амбициозная дружная и активная команда которая работает над современным финансовым сервисом Сейчас мы фокусируемся на проектах для стран Юго Восточной Азии В связи с динамичным развитием мы ищем в команду нового BI analyst с релокацией во Вьетнам Чем предстоит заниматься Взаимодействия с бизнес заказчиками по вопросам отчетности анализ требований Разработка витрин данных участие в проектировании и развитии архитектуры DWH Разработка отчетности в Power BI Автоматизация бизнес процессов Написание различной сложности SQL скриптов оптимизация SQL скриптов Возможно использование Python в целях автоматизации и организации ETL процессов Тебе подойдет вакансия если у тебя есть Математическое техническое высшее образование Опыт работы с Power BI или иным BI инструментом Понимание чем отличается оптимальный SQL запрос от неоптимального и опыт разработки сложных SQL скриптов процедур Разговорный английский язык B2 и выше Готовность к релокации в г Хошимин Вьетнам Мы предлагаем Прозрачную систему мотивации оклад ежегодные бонусы Отсутствие бюрократии высокая степень свободы Решения принимаются очень быстро Полный релокационный пакет визы билеты и страховки для сотрудника и семьи оплата отеля оформление всех документов на стороне компании релокация во Вьетнам Бесплатные обучения Тимбилдинги в странах Азии мы уже были на Филиппинах Фукуоке Бали а следующий тимбилдинг планируем на Пхукете ',
#  ' Кто мы AdGo это молодая динамично развивающаяся компания объединяющая профессионалов и новичков рынка россии скои и международнои интернет рекламы Мы работаем по всему миру применяя лучшие практики Благодаря нашему энтузиазму и сплоченной команде за 8 лет мы достигли отличных результатов Наша философия это бережное и внимательное отношение к людям Здесь вы никогда не останетесь один на один с трудностями а ваши самые невероятные и креативные идеи будут на вес золота Наша компания это простор для мыслей творчества самореализации и роста Вам будет комфортно с нами если вы придерживаетесь похожих ценностей питаете страсть к работе цените любую возможность стать лучше и опытней Мы командные игроки которые любят рисковать принимать трудные решения и ставить поистине сложные задачи Кого мы ищем Единомышленников Талантливых людей желающих найти не просто новую работу но и неограниченные возможности для профессионального роста и личного развития Обязанности обслуживание виртуальных и железных серверов от заказа до сдачи настройка инвентаризация документирование серверов и сервисов диагностика и решение железных и сетевых проблем посредством общения с саппортом хостинг провайдеров первая линия саппорта для различных команд разработки и коллег из других отделов настройка мониторинга реагирование на оповещения системы мониторинга настройка пайплайнов настройка деплоя приложений создание и развертывание из бэкапов ОС баз данных других сервисов Требования опыт администрирования RHEL based OS опыт администрирования linux приложений веб серверы базы данных почтовые серверы системы мониторинга уверенное знание TCP IP базовые знания systemd docker kubernetes gitlab ci ansible базовые знания bash python golang аналитические навыки для предотвращения и устранения неисправностей систем Будет плюсом работа с CAPSMAN mikrotik опыт работы с jupyter hub notebook умения в настройке различных типов vpn proxy Наш стек clickhouse zookeeper mysql postgresql vertica aerospike memcached redis php js golang nginx dovecot postfix roundcube gitlab docker kubernetes grafana influxdb kapacitor ELK stack openvpn wireguard ikev2 Условия Работа удал нно но с периодическими посещениями офиса в СПб 2 3 раза в месяц Рабочий день длится всего 8 часов и вы можете выбрать когда начать свой рабочий день с 9 00 до 11 00 Это значит что у вас есть больше свободного времени для личных дел и хобби У вас будет доступ к нашей шикарной корпоративной страховке Забота о вашем здоровье это наш приоритет Мы даем вам возможность иметь один дополнительный выходной день в месяц чтобы полностью расслабиться забыть о работе и заниматься тем что вам действительно нравится Каждый год мы устраиваем драйвовые корпоративные мероприятия чтобы вы могли насладиться развлечениями и почувствовать командный дух И это не просто тимбилдинг недалеко от города с эстафетой Это паром в Стамбуле яркое празднование Нового Года в Будапеште уютные улочки старого города Таллина с глинтвейном в руках подьем в горы в Архызе или создание плота как в детстве в Казани Мы предоставляем вам уникальные возможности для быстрого карьерного роста и широкого спектра интересных задач У нас всегда есть что то новое и захватывающее В нашем уютном офисе на Петроградке вы всегда найдете бесплатный кофе фрукты и овощи в любое время а также стол для тенниса и кикер чтобы вы могли расслабиться и разрядиться после трудного дня В нашей дружелюбной и сплоченной команде всегда царит атмосфера веселья и открытости к новым идеям Мы всегда готовы поделиться опытом и внимательно выслушать ваши предложения А самое главное мы терпеть не можем бюрократию поэтому все новые идеи всегда легко подхватываются в реализацию Присоединяйтесь к нам и отправьтесь с нами в это путешествие по просторам интернет рекламы Будьте частью нашего успешного и амбициозного коллектива ',
#  ' Чем предстоит заниматься Поддержкой работоспособности информационных систем и приложений собственной разработки в периметре своего отдела Kafka Yoda платформа Gravitee Jira Confluence Prometheus Keycloak Grafana NAVTEQ центральные репозитории Управление командой в целях реализации задач группы Решением инцидентов и устранением сбоев возникающих в информационных системах приложениях ИТ платформах и модулях в рамках зоны своей ответственности контролем поступающих обращений и заявок Планированием регламентных работ по обновлению версий ПО по изменению текущих настроек и конфигураций по установке информационных систем приложений ИТ платформ модулей на нового сервера а также по настройке новых программных продуктов утвержденных архитекторами отдела Анализом входящей документации для проектирования и разработки ИТ решений выработкой рекомендаций по улучшению документации по ИТ процессам Внедрением процесса обеспечивающего поддержку и предоставление ИТ сервисов ITSM в рамках функции группы Формированием и поддержание в актуальном состоянии базы знаний в зоне своей ответственности Confluence Пожелания к кандидату Аналогичный опыт от 3 х лет Опыт управления командой от 10 ти человек Знание Linux Windows Kafka Talend Gravitee языков программирования Java и Python Широкий кругозор по технологиям интеграции Контейнеризация Docker оркестрация Docker Swarm Kubernetes мониторинг Graphana Kibana Продвинутый английский язык будет преимуществом Мы предлагаем Оформление в аккредитованную IT компанию Гибридный график и комфортный офис Расширенный пакет ДМС со стоматологией выездом врачей на дом К ДМС можно подключать детей через 1 год работы Внутрикорпоративное обучение Скидки в наших магазинах и льготные условия от партнеров Бесплатная парковка Корпоративная столовая Премии по результатам работы Возможность влиять на процессы принимать решения и реализовывать свои идеи Участие в проектах федерального масштаба Работайте вместе с друзьями и получайте премию за каждого трудоустроенного друга ',
#  ' Компания Brooma является аккредитованной IT компанией специализирующейся на разработке инновационного продукта Jeffit Наша основная цель предоставить передовые IT решения которые помогут юридическим фирмам и юридическим департаментам эффективно управлять своими процессами Мы гордимся нашими клиентами среди которых такие крупные компании как Siemens Unilever Мвидео Сибур НЛМК и Лукоил У нас два офиса Головной офис расположен в Москве где работают наши Product Owner 39 ы бизнес аналитики и UX специалисты В нашем центре разработки в Новосибирске мы сосредоточены на backend и frontend разработке а также на работе QA и DevOps Мы постоянно стремимся к совершенству и привлекаем лучших специалистов в нашу команду чтобы обеспечить высокое качество наших продуктов и удовлетворение потребностей наших клиентов В настоящее время мы ищем опытного инженера DevOps Системного администратора SRE ответственного за сопровождение наших облачных продуктов и систем на стороне заказчика Мы ищем кандидата который обладает опытом работы с администрированием Ubuntu CentOS написанием скриптов на bash python работой с системами виртуализации и облачными IaaS сервисами а также опытом развертывания и обслуживания веб серверов Основные требования Опыт администрирования Ubuntu CentOS Опыт написания скриптов на bash python Опыт работы с системами виртуализации и облачными IaaS сервисами Опыт развертывания и обслуживания веб серверов Желательные навыки Знакомство со стеком технологий включающим tomcat postgresql java EE 8 spring haproxy nginx activeMQ redis Готовность работать с Windows Server и разными дистрибутивами Linux Знакомство с системами управления конфигурациями например Ansible Основные задачи Сопровождение наших облачных продуктов и систем на стороне заказчика включая мониторинг с использованием Zabbix Совместная работа с разработчиками для поиска и устранения проблем а также разбора инцидентов Деплой и масштабирование балансировка нагрузки Определение требований к серверному оборудованию Поддержка и доработка скриптов автоматизации и систем CI CD на базе Jenkins и GitLab репозитория Подготовка системного окружения для разработки Участие в формировании технических требований к компонентам и нагрузочном тестировании Мы предлагаем Работу в аккредитованной IT компании над передовым продуктом в области LegalTech ДМС после успешного завершения испытательного срока Офисный гибридный или полностью удаленный формат работы Уникальную возможность принимать решения в процессе реализации технических задач и влиять на развитие проектов и процессы в компании Атмосферу взаимного обмена знаниями и поддержки между командами Регулярные перфоманс ревью установление персональных целей и разработка плана для вашего личного развития Мы ценим рост наших сотрудников и предоставляем инструменты для их профессионального развития Отсутствие бюрократии Мы создаем условия в которых вы можете сосредоточиться на своих задачах минимизируя лишние согласования Присоединяйтесь к нам и вы получите возможность работать с передовыми технологиями развивать свои навыки и внести значимый вклад в индустрию LegalTech ',
#  ' Для основного продукта Wallcraft более 200 млн загрузок 6 млн активных пользователей в месяц ищем Senior Team lead Machine Learning Engineer который сможет усилить нашу команду Тебе предстоит заниматься исследованием и имплементацией различных алгоритмов в рекомендательной системе проводить эксперименты и оптимизировать SOTA генеративных моделей организацией эффективной работы ML отдела адаптацией и совершенствованием существующих алгоритмов Ипользуемый стэк Python Pytorch BigQuery Clickhouse Postgres Мы рассчитываем что у тебя есть опыт и знания для этой позиции А именно 5 лет опыта в роли Machine Learning Engineer желателен опыт в мобильных приложениях знание основ статистики опыт и понимание классических ML алгоритмов и DL опыт реализации и применения моделей машинного обучения в продакшене уверенное владение Python numpy pandas scipy pytorch sklearn Мы предлагаем полную занятость с гибким началом рабочего дня высокую заработную плату бонусы за результат офис в центре Пензы с панорамным видом удаленную работу предоставление всей необходимой для работы техники возглавить отдел ML вы будете работать один в начале далее возможен найм вам помощника при необходимости которого вы выберете сами ',
#  ' IBS Dunice это команда опытных разработчиков тестировщиков аналитиков дизайнеров и менеджеров Мы создаем веб сервисы и мобильные приложения которыми пользуются миллионы и помогаем молодым талантам расти и развиваться С 2012 года мы выполнили более 450 проектов для клиентов по всему миру В их числе Банк Открытие Unicredit Bank Forbes Media и более десятка других известных компаний На сегодняшний день нас уже 300 человек Головной офис IBS Dunice расположен в Таганроге а также есть офисы в Новочеркасске и Шахтах Мы ищем middle Full Stack разработчика нацеленного на результат и профессиональный рост Мы жд м от тебя Опыт коммерческой разработки на одном из серверных языков PHP Python Ruby NodeJS Опыт работы с front end технологиями JavaScript jQuery Angular React js Vue js Навыки работы с GIT Английский язык не ниже уровня Intermediate Опыт работы с реляционными MySQL PostgreSQL и NoSQL базами данных Постоянное развитие и изучение новых web технологий Мы гарантируем Официальное трудоустройство по ТК РФ Офис в центре города Развитую корпоративную культуру Бонусы корпоративная система лояльности компенсация обедов в ресторане quot Абсолют quot ДМС мерч спорт ',
#  ' Neovox Technology команда профессионалов разрабатывающая комплексные IT решения для российских и зарубежных банков контактных центров автодилеров операторов связи с 2010 года В команду IT специалистов входят высококвалифицированные сотрудники с богатым прикладным опытом Мы добавляем возможности искусственного интеллекта и машинного обучения в процесс общения с клиентами занимаемся построением интерактивных голосовых сервисов с синтезом и распознаванием речи проводим глубокую аналитику больших данных автоматизируем бизнес процессы наших клиентов Мы сами разрабатываем ПО и технологические решения для покрытия нужд контактных центров и других наших партнеров Мы ценим любознательность и активность в наших сотрудниках и поощряем их развитие Работая в нашей команде ты сможешь поучаствовать в больших и интересных проектах по самым разным направлениям Для разработки голосовых ботов на Python и JavaScript подобном языке ищем сотрудников с горящими глазами готовностью обучаться и желанием получить опыт в разработке с перспективой роста С нас доверие и приятная атмосфера В ответном письме просим написать про ваш пусть даже незначительный опыт и интересы в мире технологий Чем больше тем лучше Обязанности Разработка и сопровождение голосовых сценариев на Python 2 amp 3 и JS подобном языке Передача знаний своим коллегам Оказание поддержки коллегам из направления бизнеса Требования Знание английского языка на уровне чтения документации Любой опыт программирования Опыт работы с linux подобными операционными системами в командной строке Понимание устройства Web Условия График работы 5 2 с 9 до 18 по Московскому времени с возможностью корректировок Испытательный срок 3 месяца Официальное трудоустройство белая заработная плата и ежемесячные премии Удал нный формат работы ',
#  ' Мы делаем трейдинговую платформу на рынках Индии Бангладеша Пакистана Шри Ланки У нас уже есть пользователи продукт но мы все ещ в активном поиске product market fit а это предполагает постоянное тестирование гипотез скорость смелость работа с высокой степенью неопределенности Сейчас мы меняем нашу стратегию Из продукта который привлекает пользователей через призывы к манимейкингу мы строим продукт где обучаем пользователей работать с рисками и плавно погружаться в трейдинг без серьезных потерь денег Верим что это значительно увеличит доверие и непременно скажется на LTV и экономике продукта в целом позволит нам быстрее масштабироваться Наша компания проделала длинный путь от группы единомышленников до международной компании которая помогла развиться большому числу проектов стартапов вырасти в самостоятельный и успешный бизнес который присутствует на рынках России СНГ Латинской Америки Азии Итак сейчас мы в поисках Продуктового аналитика Обязанности Активно участвовать в дискавери процессах искать и предлагать возможности для роста метрик продуктовой команды и всей компании проводить соответствующие исследования Проектировать и продумывать дизайн А B тестов валидировать и интерпретировать результаты Активно участвовать в создании системы A B тестирования добавлять новые метрики в систему A B тестов проверять метрики на статистическую корректность Ad hoc отчеты Надо быстро выгрузить оперативный отчет для какой то задачи Искать точки роста и генерировать гипотезы по улучшению продукта Требования Свободное владение аналитическим инструментарием типа JupyterLab или аналогами Отличное знание SQL Это основной рабочий инструмент аналитика поэтому на собеседовании мы в первую очередь проверяем навыки написания SQL запросов Уверенное знание Python с аналитическими библиотеками и SQL Clickhouse MySQL Опыт проведения A B тестов и знание теоретической базы для их проведения знание математической статистики и теории вероятностей понимание сути распределений корреляций отклонений параметров репрезентативности и т п Опыт работы с любым BI инструментом Metabase PowerBI Опыт работы в коммерческом IT продукте отличное знание продуктовых метрик и их взаимосвязей Знание процессов работы с данными Опыт написания аналитических записок Хорошие знания мат анализа мат статистики в частности Опыт работы продуктовым аналитиком или аналитиком данных от 2х лет Будет плюсом Опыт создания инфраструктуры системы аналитики с нуля или е доработки в связке с devops Опыт кластеризации пользовательской базы с помощью ML методов data mining Опыт моделирования изменения метрик Опыт работы в финтех продукте Условия Удаленка или офис в Казани ИТ парк или БЦ Сфера Команда отлично работает распределенно Супер приятный коллектив здоровая атмосфера и взаимная поддержка Возможность принимать самостоятельные решения на основе подхода vision driven data informed Принимать прямое участие в создании продукта на миллионы пользователей ',
#  ' ВАКАНСИЯ С ПЕРЕЕЗДОМ В РЕСПУБЛИКУ ТАТАРСТАН Обязанности Разработка web приложений Участие в обсуждении и проработке концепций и нового функционала Участие в построении архитектуры и проектировании Взаимодействие со стажерами Студенты Алабуга Политех Требования Хорошие знания Python 3 Опыт работы с Django Sanic Tornado FastApi Опыт работы с Asyncio Опыт работы с Websocket Опыт работы с Pydantic Опыт работы с Docker Опыт работы с Git Уверенные знания REST Опыт работы с реляционными базами данных PostgreSQL MySQL Уровень уверенный Middle Условия дневная рабочая неделя 5 2 с 8 00 до 17 00 ненормированная формат работы офис работа в крупной и стабильной компании в структуре самой большой ОЭЗ в Европе транспорт до работы из г Елабуга г Набережные Челны г Менделеевск оплачиваемые отпуска и больничные гарантия профессионального роста бесплатное обучение молодую амбициозную проектно ориентированную команду командные игры мозговые штурмы реализация нестандартных задач карьерный рост при наличии и обретения в процессе работы необходимых компетенций заработная плата по результатам собеседовании ',
#  ' Тензор это аккредитованная IT компания Наш основной продукт СБИС сеть деловых коммуникаций СБИС объединяет людей и компании системы управления и учета бизнес процессы и документы в одной системе Мы ищем людей способных реализовывать крупные проекты от идеи до продакшна На этой должности у Вас не будет времени чтобы писать код самому Но Вы должны уметь это делать лучше своей команды хотя бы для того чтобы понять за пару минут насколько качественно написан код Вашим сотрудником уметь быстро разработать самому или понять чужой алгоритм В сложных случаях когда все скажут пас вам придется стать крайним и самому находить ошибки в программах ваших сотрудников Но это все иногда а обычно 90 вашего времени будет уходить на прорисовку архитектуры системы интерфейсов как пользовательских так и внутренних изучение конкурентов и новых технологий ну и конечно генерацию собственных идей Нам будет интересен Ваш опыт по следующим направлениям Управление правами Платформа мобильной разработки Удостоверяющий центр Мобильная розница События и мультимедия Функциональное тестирование Технологии которые мы используем JavaScript TypeScript inferno js Node JS C Python PostgreSQL Redis ElasticSearch ClickHouse Boost qt SQLite STL Kotlin Dagger2 RxJava2 AAC Swift UiKIT MVP MVVM Viper Мы предлагаем оформление по ТК РФ премии по итогам работы за месяц оборудованное место в комфортном офисе или возможность работать из дома в любимых тапочках компенсация спортивных абонементов ДМС помощь опытного наставника на испытательный срок гибкое начало и окончание рабочего дня свободный дресс код корпоративные скидки и бонусы от наших партнеров обучающие курсы товары и т д подарки от компании при заключении брака и рождении детей социальную поддержку при сложных жизненных ситуациях корпоративную библиотеку ']

# %%
morph = MorphAnalyzer()
stop_words = stopwords.words('russian')

corpus = [
    [
        word_norm for word in word_tokenize(doc, language='russian')
        if (word_norm := morph.normal_forms(word)[0]) not in stop_words
    ] for doc in corpus
]

corpus[:5]
# Out:
# [['finstar',
#   'financial',
#   'group',
#   'крупный',
#   'международный',
#   'холдинг',
#   'который',
#   'входить',
#   'компания',
#   'весь',
#   'мир',
#   'основной',
#   'бизнес',
#   'онлайн',
#   'кредитование',
#   'банковский',
#   'сегмент',
#   'амбициозный',
#   'дружный',
#   'активный',
#   'команда',
#   'который',
#   'работать',
#   'современный',
#   'финансовый',
#   'сервис',
#   'фокусироваться',
#   'проект',
#   'страна',
#   'юго',
#   'восточный',
#   'азия',
#   'связь',
#   'динамичный',
#   'развитие',
#   'искать',
#   'команда',
#   'новый',
#   'bi',
#   'analyst',
#   'релокация',
#   'вьетнам',
#   'предстоять',
#   'заниматься',
#   'взаимодействие',
#   'бизнес',
#   'заказчик',
#   'вопрос',
#   'отчётность',
#   'анализ',
#   'требование',
#   'разработка',
#   'витрина',
#   'данные',
#   'участие',
#   'проектирование',
#   'развитие',
#   'архитектура',
#   'dwh',
#   'разработка',
#   'отчётность',
#   'power',
#   'bi',
#   'автоматизация',
#   'бизнес',
#   'процесс',
#   'написание',
#   'различный',
#   'сложность',
#   'sql',
#   'скрипт',
#   'оптимизация',
#   'sql',
#   'скрипт',
#   'возможно',
#   'использование',
#   'python',
#   'цель',
#   'автоматизация',
#   'организация',
#   'etl',
#   'процесс',
#   'подойти',
#   'вакансия',
#   'математический',
#   'технический',
#   'высокий',
#   'образование',
#   'опыт',
#   'работа',
#   'power',
#   'bi',
#   'иной',
#   'bi',
#   'инструмент',
#   'понимание',
#   'отличаться',
#   'оптимальный',
#   'sql',
#   'запрос',
#   'неоптимальный',
#   'опыт',
#   'разработка',
#   'сложный',
#   'sql',
#   'скрипт',
#   'процедура',
#   'разговорный',
#   'английский',
#   'язык',
#   'b2',
#   'выше',
#   'готовность',
#   'релокация',
#   'г',
#   'хошимин',
#   'вьетнам',
#   'предлагать',
#   'прозрачный',
#   'система',
#   'мотивация',
#   'оклад',
#   'ежегодный',
#   'бонус',
#   'отсутствие',
#   'бюрократия',
#   'высокий',
#   'степень',
#   'свобода',
#   'решение',
#   'приниматься',
#   'очень',
#   'быстро',
#   'полный',
#   'релокационный',
#   'пакет',
#   'виза',
#   'билет',
#   'страховка',
#   'сотрудник',
#   'семья',
#   'оплата',
#   'отель',
#   'оформление',
#   'весь',
#   'документ',
#   'сторона',
#   'компания',
#   'релокация',
#   'вьетнам',
#   'бесплатный',
#   'обучение',
#   'тимбилдинг',
#   'страна',
#   'азия',
#   'филиппины',
#   'фукуока',
#   'бали',
#   'следующий',
#   'тимбилдинг',
#   'планировать',
#   'пхукет'],
#  ['adgo',
#   'это',
#   'молодой',
#   'динамично',
#   'развивающийся',
#   'компания',
#   'объединять',
#   'профессионал',
#   'новичок',
#   'рынок',
#   'россия',
#   'ской',
#   'международноить',
#   'интернет',
#   'реклама',
#   'работать',
#   'весь',
#   'мир',
#   'применять',
#   'хороший',
#   'практика',
#   'благодаря',
#   'наш',
#   'энтузиазм',
#   'сплотить',
#   'команда',
#   '8',
#   'год',
#   'достигнуть',
#   'отличный',
#   'результат',
#   'наш',
#   'философия',
#   'это',
#   'бережный',
#   'внимательный',
#   'отношение',
#   'человек',
#   'остаться',
#   'трудность',
#   'ваш',
#   'самый',
#   'невероятный',
#   'креативный',
#   'идея',
#   'вес',
#   'золото',
#   'наш',
#   'компания',
#   'это',
#   'простор',
#   'мысль',
#   'творчество',
#   'самореализация',
#   'рост',
#   'комфортно',
#   'придерживаться',
#   'похожий',
#   'ценность',
#   'питать',
#   'страсть',
#   'работа',
#   'ценить',
#   'любой',
#   'возможность',
#   'стать',
#   'хороший',
#   'опытный',
#   'командный',
#   'игрок',
#   'который',
#   'любить',
#   'рисковать',
#   'принимать',
#   'трудный',
#   'решение',
#   'ставить',
#   'поистине',
#   'сложный',
#   'задача',
#   'искать',
#   'единомышленник',
#   'талантливый',
#   'человек',
#   'желать',
#   'найти',
#   'просто',
#   'новый',
#   'работа',
#   'неограниченный',
#   'возможность',
#   'профессиональный',
#   'рост',
#   'личный',
#   'развитие',
#   'обязанность',
#   'обслуживание',
#   'виртуальный',
#   'железный',
#   'сервер',
#   'заказ',
#   'сдача',
#   'настройка',
#   'инвентаризация',
#   'документирование',
#   'сервер',
#   'сервис',
#   'диагностика',
#   'решение',
#   'железный',
#   'сетевой',
#   'проблема',
#   'посредством',
#   'общение',
#   'саппорт',
#   'хостинг',
#   'провайдер',
#   'первый',
#   'линия',
#   'саппорт',
#   'различный',
#   'команда',
#   'разработка',
#   'коллега',
#   'отдел',
#   'настройка',
#   'мониторинг',
#   'реагирование',
#   'оповещение',
#   'система',
#   'мониторинг',
#   'настройка',
#   'пайплайн',
#   'настройка',
#   'деплоить',
#   'приложение',
#   'создание',
#   'развёртывание',
#   'бэкап',
#   'ос',
#   'база',
#   'данные',
#   'сервис',
#   'требование',
#   'опыт',
#   'администрирование',
#   'rhel',
#   'based',
#   'os',
#   'опыт',
#   'администрирование',
#   'linux',
#   'приложение',
#   'веб',
#   'сервер',
#   'база',
#   'данные',
#   'почтовый',
#   'сервер',
#   'система',
#   'мониторинг',
#   'уверенный',
#   'знание',
#   'tcp',
#   'ip',
#   'базовый',
#   'знание',
#   'systemd',
#   'docker',
#   'kubernetes',
#   'gitlab',
#   'ci',
#   'ansible',
#   'базовый',
#   'знание',
#   'bash',
#   'python',
#   'golang',
#   'аналитический',
#   'навык',
#   'предотвращение',
#   'устранение',
#   'неисправность',
#   'система',
#   'плюс',
#   'работа',
#   'capsman',
#   'mikrotik',
#   'опыт',
#   'работа',
#   'jupyter',
#   'hub',
#   'notebook',
#   'умение',
#   'настройка',
#   'различный',
#   'тип',
#   'vpn',
#   'proxy',
#   'наш',
#   'стек',
#   'clickhouse',
#   'zookeeper',
#   'mysql',
#   'postgresql',
#   'vertica',
#   'aerospike',
#   'memcached',
#   'redis',
#   'php',
#   'js',
#   'golang',
#   'nginx',
#   'dovecot',
#   'postfix',
#   'roundcube',
#   'gitlab',
#   'docker',
#   'kubernetes',
#   'grafana',
#   'influxdb',
#   'kapacitor',
#   'elk',
#   'stack',
#   'openvpn',
#   'wireguard',
#   'ikev2',
#   'условие',
#   'работа',
#   'удалой',
#   'нно',
#   'периодический',
#   'посещение',
#   'офис',
#   'спб',
#   '2',
#   '3',
#   'месяц',
#   'рабочий',
#   'день',
#   'длиться',
#   'весь',
#   '8',
#   'час',
#   'мочь',
#   'выбрать',
#   'начать',
#   'свой',
#   'рабочий',
#   'день',
#   '9',
#   '00',
#   '11',
#   '00',
#   'это',
#   'значит',
#   'большой',
#   'свободный',
#   'время',
#   'личный',
#   'дело',
#   'хобби',
#   'доступ',
#   'наш',
#   'шикарный',
#   'корпоративный',
#   'страховка',
#   'забота',
#   'ваш',
#   'здоровье',
#   'это',
#   'наш',
#   'приоритет',
#   'давать',
#   'возможность',
#   'иметь',
#   'дополнительный',
#   'выходной',
#   'день',
#   'месяц',
#   'полностью',
#   'расслабиться',
#   'забыть',
#   'работа',
#   'заниматься',
#   'действительно',
#   'нравиться',
#   'каждый',
#   'год',
#   'устраивать',
#   'драйвовый',
#   'корпоративный',
#   'мероприятие',
#   'мочь',
#   'насладиться',
#   'развлечение',
#   'почувствовать',
#   'командный',
#   'дух',
#   'это',
#   'просто',
#   'тимбилдинг',
#   'недалеко',
#   'город',
#   'эстафета',
#   'это',
#   'паром',
#   'стамбул',
#   'яркий',
#   'празднование',
#   'новый',
#   'год',
#   'будапешт',
#   'уютный',
#   'улочка',
#   'старое',
#   'город',
#   'таллин',
#   'глинтвейн',
#   'рука',
#   'подье',
#   'гора',
#   'архыз',
#   'создание',
#   'плот',
#   'детство',
#   'казань',
#   'предоставлять',
#   'уникальный',
#   'возможность',
#   'быстрый',
#   'карьерный',
#   'рост',
#   'широкий',
#   'спектр',
#   'интересный',
#   'задача',
#   'новый',
#   'захватывать',
#   'наш',
#   'уютный',
#   'офис',
#   'петроградка',
#   'найти',
#   'бесплатный',
#   'кофе',
#   'фрукт',
#   'овощ',
#   'любой',
#   'время',
#   'также',
#   'стол',
#   'теннис',
#   'кикер',
#   'мочь',
#   'расслабиться',
#   'разрядиться',
#   'трудный',
#   'день',
#   'наш',
#   'дружелюбный',
#   'сплотить',
#   'команда',
#   'царить',
#   'атмосфера',
#   'веселие',
#   'открытость',
#   'новый',
#   'идея',
#   'готовый',
#   'поделиться',
#   'опыт',
#   'внимательно',
#   'выслушать',
#   'ваш',
#   'предложение',
#   'самый',
#   'главное',
#   'терпеть',
#   'мочь',
#   'бюрократия',
#   'поэтому',
#   'всё',
#   'новый',
#   'идея',
#   'легко',
#   'подхватываться',
#   'реализация',
#   'присоединяться',
#   'отправиться',
#   'это',
#   'путешествие',
#   'простор',
#   'интернет',
#   'реклама',
#   'часть',
#   'наш',
#   'успешный',
#   'амбициозный',
#   'коллектив'],
#  ['предстоять',
#   'заниматься',
#   'поддержка',
#   'работоспособность',
#   'информационный',
#   'система',
#   'приложение',
#   'собственный',
#   'разработка',
#   'периметр',
#   'свой',
#   'отдел',
#   'kafka',
#   'yoda',
#   'платформа',
#   'gravitee',
#   'jira',
#   'confluence',
#   'prometheus',
#   'keycloak',
#   'grafana',
#   'navteq',
#   'центральный',
#   'репозиторий',
#   'управление',
#   'команда',
#   'цель',
#   'реализация',
#   'задача',
#   'группа',
#   'решение',
#   'инцидент',
#   'устранение',
#   'сбой',
#   'возникать',
#   'информационный',
#   'система',
#   'приложение',
#   'ит',
#   'платформа',
#   'модуль',
#   'рамка',
#   'зона',
#   'свой',
#   'ответственность',
#   'контроль',
#   'поступать',
#   'обращение',
#   'заявка',
#   'планирование',
#   'регламентный',
#   'работа',
#   'обновление',
#   'версия',
#   'изменение',
#   'текущий',
#   'настройка',
#   'конфигурация',
#   'установка',
#   'информационный',
#   'система',
#   'приложение',
#   'ит',
#   'платформа',
#   'модуль',
#   'новый',
#   'сервер',
#   'также',
#   'настройка',
#   'новый',
#   'программный',
#   'продукт',
#   'утвердить',
#   'архитектор',
#   'отдел',
#   'анализ',
#   'входящий',
#   'документация',
#   'проектирование',
#   'разработка',
#   'ит',
#   'решение',
#   'выработка',
#   'рекомендация',
#   'улучшение',
#   'документация',
#   'ит',
#   'процесс',
#   'внедрение',
#   'процесс',
#   'обеспечивать',
#   'поддержка',
#   'предоставление',
#   'ит',
#   'сервис',
#   'itsm',
#   'рамка',
#   'функция',
#   'группа',
#   'формирование',
#   'поддержание',
#   'актуальный',
#   'состояние',
#   'база',
#   'знание',
#   'зона',
#   'свой',
#   'ответственность',
#   'confluence',
#   'пожелание',
#   'кандидат',
#   'аналогичный',
#   'опыт',
#   '3',
#   'х',
#   'год',
#   'опыт',
#   'управление',
#   'команда',
#   '10',
#   'ти',
#   'человек',
#   'знание',
#   'linux',
#   'windows',
#   'kafka',
#   'talend',
#   'gravitee',
#   'язык',
#   'программирование',
#   'java',
#   'python',
#   'широкий',
#   'кругозор',
#   'технология',
#   'интеграция',
#   'контейнеризация',
#   'docker',
#   'оркестрация',
#   'docker',
#   'swarm',
#   'kubernetes',
#   'мониторинг',
#   'graphana',
#   'kibana',
#   'продвинуть',
#   'английский',
#   'язык',
#   'преимущество',
#   'предлагать',
#   'оформление',
#   'аккредитовать',
#   'it',
#   'компания',
#   'гибридный',
#   'график',
#   'комфортный',
#   'офис',
#   'расширить',
#   'пакет',
#   'дмс',
#   'стоматология',
#   'выезд',
#   'врач',
#   'дом',
#   'дмс',
#   'подключать',
#   'ребёнок',
#   '1',
#   'год',
#   'работа',
#   'внутрикорпоративный',
#   'обучение',
#   'скидка',
#   'наш',
#   'магазин',
#   'льготный',
#   'условие',
#   'партнёр',
#   'бесплатный',
#   'парковка',
#   'корпоративный',
#   'столовая',
#   'премия',
#   'результат',
#   'работа',
#   'возможность',
#   'влиять',
#   'процесс',
#   'принимать',
#   'решение',
#   'реализовывать',
#   'свой',
#   'идея',
#   'участие',
#   'проект',
#   'федеральный',
#   'масштаб',
#   'работать',
#   'вместе',
#   'друг',
#   'получать',
#   'премия',
#   'каждый',
#   'трудоустроить',
#   'друг'],
#  ['компания',
#   'brooma',
#   'являться',
#   'аккредитовать',
#   'it',
#   'компания',
#   'специализироваться',
#   'разработка',
#   'инновационный',
#   'продукт',
#   'jeffit',
#   'наш',
#   'основный',
#   'цель',
#   'предоставить',
#   'передовой',
#   'it',
#   'решение',
#   'который',
#   'помочь',
#   'юридический',
#   'фирма',
#   'юридический',
#   'департамент',
#   'эффективно',
#   'управлять',
#   'свой',
#   'процесс',
#   'гордиться',
#   'наш',
#   'клиент',
#   'среди',
#   'который',
#   'крупный',
#   'компания',
#   'siemens',
#   'unilever',
#   'мвидео',
#   'сибур',
#   'нлмк',
#   'лукоить',
#   'офис',
#   'головной',
#   'офис',
#   'расположить',
#   'москва',
#   'работать',
#   'наш',
#   'product',
#   'owner',
#   '39',
#   'ы',
#   'бизнес',
#   'аналитик',
#   'ux',
#   'специалист',
#   'наш',
#   'центр',
#   'разработка',
#   'новосибирск',
#   'сосредоточить',
#   'backend',
#   'frontend',
#   'разработка',
#   'также',
#   'работа',
#   'qa',
#   'devops',
#   'постоянно',
#   'стремиться',
#   'совершенство',
#   'привлекать',
#   'хороший',
#   'специалист',
#   'наш',
#   'команда',
#   'обеспечить',
#   'высокий',
#   'качество',
#   'наш',
#   'продукт',
#   'удовлетворение',
#   'потребность',
#   'наш',
#   'клиент',
#   'настоящий',
#   'время',
#   'искать',
#   'опытный',
#   'инженер',
#   'devops',
#   'системный',
#   'администратор',
#   'sre',
#   'ответственный',
#   'сопровождение',
#   'наш',
#   'облачный',
#   'продукт',
#   'система',
#   'сторона',
#   'заказчик',
#   'искать',
#   'кандидат',
#   'который',
#   'обладать',
#   'опыт',
#   'работа',
#   'администрирование',
#   'ubuntu',
#   'centos',
#   'написание',
#   'скрипт',
#   'bash',
#   'python',
#   'работа',
#   'система',
#   'виртуализация',
#   'облачный',
#   'iaas',
#   'сервис',
#   'также',
#   'опыт',
#   'развёртывание',
#   'обслуживание',
#   'веб',
#   'сервер',
#   'основной',
#   'требование',
#   'опыт',
#   'администрирование',
#   'ubuntu',
#   'centos',
#   'опыт',
#   'написание',
#   'скрипт',
#   'bash',
#   'python',
#   'опыт',
#   'работа',
#   'система',
#   'виртуализация',
#   'облачный',
#   'iaas',
#   'сервис',
#   'опыт',
#   'развёртывание',
#   'обслуживание',
#   'веб',
#   'сервер',
#   'желательный',
#   'навык',
#   'знакомство',
#   'стек',
#   'технология',
#   'включать',
#   'tomcat',
#   'postgresql',
#   'java',
#   'ee',
#   '8',
#   'spring',
#   'haproxy',
#   'nginx',
#   'activemq',
#   'redis',
#   'готовность',
#   'работать',
#   'windows',
#   'server',
#   'разный',
#   'дистрибутив',
#   'linux',
#   'знакомство',
#   'система',
#   'управление',
#   'конфигурация',
#   'например',
#   'ansible',
#   'основной',
#   'задача',
#   'сопровождение',
#   'наш',
#   'облачный',
#   'продукт',
#   'система',
#   'сторона',
#   'заказчик',
#   'включая',
#   'мониторинг',
#   'использование',
#   'zabbix',
#   'совместный',
#   'работа',
#   'разработчик',
#   'поиск',
#   'устранение',
#   'проблема',
#   'также',
#   'разбор',
#   'инцидент',
#   'деплый',
#   'масштабирование',
#   'балансировка',
#   'нагрузка',
#   'определение',
#   'требование',
#   'серверный',
#   'оборудование',
#   'поддержка',
#   'доработка',
#   'скрипт',
#   'автоматизация',
#   'система',
#   'ci',
#   'cd',
#   'база',
#   'jenkins',
#   'gitlab',
#   'репозиторий',
#   'подготовка',
#   'системный',
#   'окружение',
#   'разработка',
#   'участие',
#   'формирование',
#   'технический',
#   'требование',
#   'компонент',
#   'нагрузочный',
#   'тестирование',
#   'предлагать',
#   'работа',
#   'аккредитовать',
#   'it',
#   'компания',
#   'передовой',
#   'продукт',
#   'область',
#   'legaltech',
#   'дмс',
#   'успешный',
#   'завершение',
#   'испытательный',
#   'срок',
#   'офисный',
#   'гибридный',
#   'полностью',
#   'удалённый',
#   'формат',
#   'работа',
#   'уникальный',
#   'возможность',
#   'принимать',
#   'решение',
#   'процесс',
#   'реализация',
#   'технический',
#   'задача',
#   'влиять',
#   'развитие',
#   'проект',
#   'процесс',
#   'компания',
#   'атмосфера',
#   'взаимный',
#   'обмен',
#   'знание',
#   'поддержка',
#   'команда',
#   'регулярный',
#   'перформанс',
#   'ревить',
#   'установление',
#   'персональный',
#   'цель',
#   'разработка',
#   'план',
#   'ваш',
#   'личный',
#   'развитие',
#   'ценить',
#   'рост',
#   'наш',
#   'сотрудник',
#   'предоставлять',
#   'инструмент',
#   'профессиональный',
#   'развитие',
#   'отсутствие',
#   'бюрократия',
#   'создавать',
#   'условие',
#   'который',
#   'мочь',
#   'сосредоточиться',
#   'свой',
#   'задача',
#   'минимизировать',
#   'лишний',
#   'согласование',
#   'присоединяться',
#   'получить',
#   'возможность',
#   'работать',
#   'передовой',
#   'технология',
#   'развивать',
#   'свой',
#   'навык',
#   'внести',
#   'значимый',
#   'вклад',
#   'индустрия',
#   'legaltech'],
#  ['основный',
#   'продукт',
#   'wallcraft',
#   '200',
#   'млн',
#   'загрузка',
#   '6',
#   'млн',
#   'активный',
#   'пользователь',
#   'месяц',
#   'искать',
#   'senior',
#   'team',
#   'lead',
#   'machine',
#   'learning',
#   'engineer',
#   'который',
#   'смочь',
#   'усилить',
#   'наш',
#   'команда',
#   'предстоять',
#   'заниматься',
#   'исследование',
#   'имплементация',
#   'различный',
#   'алгоритм',
#   'рекомендательный',
#   'система',
#   'проводить',
#   'эксперимент',
#   'оптимизировать',
#   'sota',
#   'генеративный',
#   'модель',
#   'организация',
#   'эффективный',
#   'работа',
#   'ml',
#   'отдел',
#   'адаптация',
#   'совершенствование',
#   'существующий',
#   'алгоритм',
#   'ипользовать',
#   'стэк',
#   'python',
#   'pytorch',
#   'bigquery',
#   'clickhouse',
#   'postgres',
#   'рассчитывать',
#   'опыт',
#   'знание',
#   'позиция',
#   'именно',
#   '5',
#   'год',
#   'опыт',
#   'роль',
#   'machine',
#   'learning',
#   'engineer',
#   'желательный',
#   'опыт',
#   'мобильный',
#   'приложение',
#   'знание',
#   'основа',
#   'статистика',
#   'опыт',
#   'понимание',
#   'классический',
#   'ml',
#   'алгоритм',
#   'dl',
#   'опыт',
#   'реализация',
#   'применение',
#   'модель',
#   'машинный',
#   'обучение',
#   'продакшен',
#   'уверенный',
#   'владение',
#   'python',
#   'numpy',
#   'pandas',
#   'scipy',
#   'pytorch',
#   'sklearn',
#   'предлагать',
#   'полный',
#   'занятость',
#   'гибкий',
#   'начало',
#   'рабочий',
#   'день',
#   'высокий',
#   'заработный',
#   'плата',
#   'бонус',
#   'результат',
#   'офис',
#   'центр',
#   'пенза',
#   'панорамный',
#   'вид',
#   'удалённый',
#   'работа',
#   'предоставление',
#   'весь',
#   'необходимый',
#   'работа',
#   'техника',
#   'возглавить',
#   'отдел',
#   'ml',
#   'работать',
#   'начало',
#   'далее',
#   'возможный',
#   'наём',
#   'помощник',
#   'необходимость',
#   'который',
#   'выбрать']]

# %%
df['description'] = corpus
df.head(3)
# Out:
#          id                                        description    salary
# 0  88979575  [finstar, financial, group, крупный, междунаро...  178780.0
# 1  91380259  [adgo, это, молодой, динамично, развивающийся,...  150000.0
# 2  90633183  [предстоять, заниматься, поддержка, работоспос...  250000.0

# %%
df.to_pickle('../storage/df_vacancies_2k.pkl')

# %%
path = '../storage/corpus_vacancies.pkl'

# with open(path, 'wb') as f:
#     pickle.dump(corpus, f)

# with open(path, 'rb') as f:
#     corpus = pickle.load(f)

# %%
import pickle
z = [1, 2 ,    3, 4, 5, [1, 2, 2, 1]]
with open('\\\\pns\\data\\a.pkl', 'rb') as f:
    # pickle.dump(z, f)
    print(pickle.load(f))
# Out:
# [1, 2, 3, 4, 5, [1, 2, 2, 1]]

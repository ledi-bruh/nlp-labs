# %%
import aiohttp
import asyncio
import numpy as np
import pickle
import re
import typing as t
import nltk
from nltk.tokenize import word_tokenize
from pymorphy3 import MorphAnalyzer

nltk.download('punkt')
nltk.download('stopwords')

from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\podov\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\podov\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ## Test

# %%
answers = {}

async def fetch(session: aiohttp.ClientSession, url: str, id):
    async with session.get(url) as response:
        await asyncio.sleep((1 + np.random.sample()) * np.random.randint(1, 4))
        answers[id] = await response.json()


async def main():
    semaphore = asyncio.Semaphore(7)
    
    async def sem_task(task):
        async with semaphore:
            return await task
    
    async with aiohttp.ClientSession() as session:
        tasks = []
        ids = np.arange(2)
        np.random.shuffle(ids)
        for id in ids:
            tasks.append(
                sem_task(fetch(session, f'http://127.0.0.1:10005/test/{id}', id))
            )
        await asyncio.gather(*tasks, return_exceptions=False)

# %%
await main()

# %%
answers
# Out:
# {0: {'detail': 'Too Many Requests'}, 1: {'detail': 'Too Many Requests'}}

# %% [markdown]
# ## Not test

# %%
async def sema(n_cor: int, tasks: list) -> None:
    semaphore = asyncio.Semaphore(n_cor)

    async def sem_task(task):
        async with semaphore:
            return await task

    tasks = [sem_task(task) for task in tasks]
    await asyncio.gather(*tasks)

# %%
res = {}

# %%
async def fetch(session: aiohttp.ClientSession, url: str, payload: dict, storage, id):
    async with session.get(url, params=payload) as response:
        await asyncio.sleep(1 + np.random.sample())
        storage[id] = await response.json()

# %%
async with aiohttp.ClientSession() as session:
    tasks = []
    for i in range(20):
        url = f'https://api.hh.ru/vacancies'
        payload = {
            'page': i,
            'per_page': 100,
            'text': 'python',
            'area': 113,  # Россия
            'currency': 'RUR',  # Рубль
            'only_with_salary': 'true',
        }
        tasks.append(fetch(session, url, payload, res, i))
    await sema(7, tasks)

# %%
res.keys()
# Out:
# dict_keys([0, 3, 6, 1, 2, 5, 4, 7, 10, 8, 9, 12, 11, 13, 14, 15, 16, 17, 18, 19])

# %%
for k in res:
    print(res[k]['per_page'], res[k]['pages'], res[k]['page'])
# Out:
# 100 20 0
# 100 20 3
# 100 20 6
# 100 20 1
# 100 20 2
# 100 20 5
# 100 20 4
# 100 20 7
# 100 20 10
# 100 20 8
# 100 20 9
# 100 20 12
# 100 20 11
# 100 20 13
# 100 20 14
# 100 20 15
# 100 20 16
# 100 20 17
# 100 20 18
# 100 20 19

# %% [markdown]
# max = 7 запросов / сек
#
# p.s. и уменьшается под конец?

# %%
ids = {
    vacancy['id']
    for page in res.values()
    for vacancy in page['items']
}
len(ids)
# Out:
# 2000

# %%
ids
# Out:
# {'87749899',
#  '87375438',
#  '86827006',
#  '87281935',
#  '88043112',
#  '87800849',
#  '46236237',
#  '87415398',
#  '86771770',
#  '69558404',
#  '86687911',
#  '87844863',
#  '87733672',
#  '87291701',
#  '86882242',
#  '81726419',
#  '87981747',
#  '87820115',
#  '88024584',
#  '83078030',
#  '87011395',
#  '82310598',
#  '87613125',
#  '87514811',
#  '87831521',
#  '84399422',
#  '87234774',
#  '87841519',
#  '77114173',
#  '87255803',
#  '87899823',
#  '87624911',
#  '73313510',
#  '87607335',
#  '85990200',
#  '87934803',
#  '86330756',
#  '87168696',
#  '87766146',
#  '86571284',
#  '85725045',
#  '87669349',
#  '87907521',
#  '87679572',
#  '87522840',
#  '87448622',
#  '86631667',
#  '87419095',
#  '87967222',
#  '87230775',
#  '87657510',
#  '86931980',
#  '84496185',
#  '87557768',
#  '87972467',
#  '87426344',
#  '86410879',
#  '87481366',
#  '86336362',
#  '86602786',
#  '80433705',
#  '86857413',
#  '86330827',
#  '87150635',
#  '88005156',
#  '87820054',
#  '87614164',
#  '87406300',
#  '87725271',
#  '83406279',
#  '86872174',
#  '87817007',
#  '83965537',
#  '86241759',
#  '86631893',
#  '88042953',
#  '87548665',
#  '87464083',
#  '86283698',
#  '83935851',
#  '88041797',
#  '87830388',
#  '86916879',
#  '86574702',
#  '86789590',
#  '82535699',
#  '81959653',
#  '87720094',
#  '86883086',
#  '86869565',
#  '87949004',
#  '86653846',
#  '77806185',
#  '86517920',
#  '86598530',
#  '86690002',
#  '86664050',
#  '82395772',
#  '85898832',
#  '86486023',
#  '86084056',
#  '87695919',
#  '87450800',
#  '87573354',
#  '87466132',
#  '81358092',
#  '88032048',
#  '87910651',
#  '86796256',
#  '77432222',
#  '87771844',
#  '86827308',
#  '87747220',
#  '86712156',
#  '87823932',
#  '87150685',
#  '87015316',
#  '87328156',
#  '88059541',
#  '86689139',
#  '87673370',
#  '87203932',
#  '87824412',
#  '87802336',
#  '86930831',
#  '87303736',
#  '84417385',
#  '87535523',
#  '85953151',
#  '86603888',
#  '87178472',
#  '86916703',
#  '85256956',
#  '86963317',
#  '86085894',
#  '86699674',
#  '85439665',
#  '86730494',
#  '86913734',
#  '86712642',
#  '87846814',
#  '85642679',
#  '87498616',
#  '86687762',
#  '87588416',
#  '87144671',
#  '80219369',
#  '86720920',
#  '87662963',
#  '86921312',
#  '86942049',
#  '87114477',
#  '85718778',
#  '76709182',
#  '86925323',
#  '87679608',
#  '81649860',
#  '86631899',
#  '87521982',
#  '86880484',
#  '86911725',
#  '87738562',
#  '84706608',
#  '87677890',
#  '87610673',
#  '87398664',
#  '87294756',
#  '86793056',
#  '87404684',
#  '87328546',
#  '86708534',
#  '86050313',
#  '85621834',
#  '87679163',
#  '87526774',
#  '86317502',
#  '88019288',
#  '87404724',
#  '87434877',
#  '87024015',
#  '84396948',
#  '85935506',
#  '84571062',
#  '87636007',
#  '84531761',
#  '86941306',
#  '87303318',
#  '87170054',
#  '87615622',
#  '82256640',
#  '87596149',
#  '87570540',
#  '87678550',
#  '87499651',
#  '87685848',
#  '84956073',
#  '88064035',
#  '86121137',
#  '87405430',
#  '87437286',
#  '87820585',
#  '87533195',
#  '87822966',
#  '86919987',
#  '86651216',
#  '86671817',
#  '87826245',
#  '87842463',
#  '86905340',
#  '87712592',
#  '82632615',
#  '83740435',
#  '86010777',
#  '87796194',
#  '86794657',
#  '85049037',
#  '85987178',
#  '86535531',
#  '87460004',
#  '85138625',
#  '87730348',
#  '86528150',
#  '87645449',
#  '87417024',
#  '87646548',
#  '86564778',
#  '73718008',
#  '87744641',
#  '77114174',
#  '87960978',
#  '87611206',
#  '84101593',
#  '88005297',
#  '87308673',
#  '87989036',
#  '86173321',
#  '87927087',
#  '86631894',
#  '87588084',
#  '87405364',
#  '87708231',
#  '82632673',
#  '87968766',
#  '86718516',
#  '87795042',
#  '86927458',
#  '86979718',
#  '69962567',
#  '87687287',
#  '86688505',
#  '86921397',
#  '85220285',
#  '87162241',
#  '87911749',
#  '86861432',
#  '87955733',
#  '83560177',
#  '87788890',
#  '81728519',
#  '86775403',
#  '87745680',
#  '87287214',
#  '87856056',
#  '84272712',
#  '87662050',
#  '72687495',
#  '87845885',
#  '87905647',
#  '87540333',
#  '87608302',
#  '87301901',
#  '79133906',
#  '87859183',
#  '86811468',
#  '86742190',
#  '86298678',
#  '86622525',
#  '86765253',
#  '81404061',
#  '86707452',
#  '87293360',
#  '87886260',
#  '87264917',
#  '87394973',
#  '87585882',
#  '87752007',
#  '86663877',
#  '84874290',
#  '86828117',
#  '86680239',
#  '87613469',
#  '85655651',
#  '86985987',
#  '87415261',
#  '87172869',
#  '87854569',
#  '86589908',
#  '87640345',
#  '87850705',
#  '87744517',
#  '87941445',
#  '86608837',
#  '85713094',
#  '87854357',
#  '87621323',
#  '86219022',
#  '87278123',
#  '86773402',
#  '86074086',
#  '87960282',
#  '79002351',
#  '86031441',
#  '82902035',
#  '86739744',
#  '87866992',
#  '87149186',
#  '87624831',
#  '86844036',
#  '86933235',
#  '87861132',
#  '87206123',
#  '85979039',
#  '85956877',
#  '87369397',
#  '87687676',
#  '87950452',
#  '85833142',
#  '87338054',
#  '87327068',
#  '88001744',
#  '87300068',
#  '87529630',
#  '87992797',
#  '87885096',
#  '86741580',
#  '87150221',
#  '88050443',
#  '87616928',
#  '87802216',
#  '87304321',
#  '87199252',
#  '86611398',
#  '86880613',
#  '87987732',
#  '86605853',
#  '86631898',
#  '87726169',
#  '69970105',
#  '86546482',
#  '87274153',
#  '86631666',
#  '84634914',
#  '87712391',
#  '87226850',
#  '86793832',
#  '86885912',
#  '87787631',
#  '80073164',
#  '87419031',
#  '86075319',
#  '88058766',
#  '86273420',
#  '87986215',
#  '87912358',
#  '87328656',
#  '87918938',
#  '87783522',
#  '87596151',
#  '87889676',
#  '87136771',
#  '88060168',
#  '86789656',
#  '87127228',
#  '86993871',
#  '86815529',
#  '86610052',
#  '86266672',
#  '76479555',
#  '85855304',
#  '87126403',
#  '85292078',
#  '86888016',
#  '86992395',
#  '87134615',
#  '85470352',
#  '87788646',
#  '86380996',
#  '87759151',
#  '87701940',
#  '82952819',
#  '85855303',
#  '85608307',
#  '81065269',
#  '87786868',
#  '77188056',
#  '86890138',
#  '87126407',
#  '87505663',
#  '82952811',
#  '87498624',
#  '87774396',
#  '86731243',
#  '87959604',
#  '87702428',
#  '85494165',
#  '82326066',
#  '86667054',
#  '83779911',
#  '87966900',
#  '82952809',
#  '87643617',
#  '87972201',
#  '87789490',
#  '87171391',
#  '86345826',
#  '88023920',
#  '87859874',
#  '87957089',
#  '87225149',
#  '87772622',
#  '86891895',
#  '86631889',
#  '86789628',
#  '87702427',
#  '86096962',
#  '86093969',
#  '86895171',
#  '86631658',
#  '87505588',
#  '87420112',
#  '87497062',
#  '87633442',
#  '87309122',
#  '87628675',
#  '84073977',
#  '87640093',
#  '83779889',
#  '86672970',
#  '87928135',
#  '87913313',
#  '87123765',
#  '86922032',
#  '87412107',
#  '87179017',
#  '78147849',
#  '83409590',
#  '83265450',
#  '86667913',
#  '87435276',
#  '86722575',
#  '80502484',
#  '86942050',
#  '86876427',
#  '87655533',
#  '83564921',
#  '86795178',
#  '87989064',
#  '87935950',
#  '87677397',
#  '85770964',
#  '87627862',
#  '87280329',
#  '87935012',
#  '87168667',
#  '86797160',
#  '87676392',
#  '87502761',
#  '87173776',
#  '87765967',
#  '87488618',
#  '86253331',
#  '87391286',
#  '86989293',
#  '86870863',
#  '87674219',
#  '86445302',
#  '85577565',
#  '87726479',
#  '84380198',
#  '86249885',
#  '86125014',
#  '87655783',
#  '87401604',
#  '83251769',
#  '84706609',
#  '86663216',
#  '86982869',
#  '86714023',
#  '87624992',
#  '85936803',
#  '87541129',
#  '87209443',
#  '86874722',
#  '86675291',
#  '82952813',
#  '86598360',
#  '87616902',
#  '88048435',
#  '87211272',
#  '87298406',
#  '87400798',
#  '87743857',
#  '87462719',
#  '82638269',
#  '82837538',
#  '85430547',
#  '87168831',
#  '88062021',
#  '87861133',
#  '86178643',
#  '87888559',
#  '87242217',
#  '87593475',
#  '86906646',
#  '87189455',
#  '86791041',
#  '88015297',
#  '87784364',
#  '86742939',
#  '87731124',
#  '87409516',
#  '84148599',
#  '87874265',
#  '79406955',
#  '86614487',
#  '87385245',
#  '86631661',
#  '87745453',
#  '87435241',
#  '87191163',
#  '86671761',
#  '87606206',
#  '87277796',
#  '87153785',
#  '87676583',
#  '87320865',
#  '87851523',
#  '86058310',
#  '86519796',
#  '86736346',
#  '87692174',
#  '86627294',
#  '86669933',
#  '86173325',
#  '87822234',
#  '87769746',
#  '87950097',
#  '88001192',
#  '86789577',
#  '87394229',
#  '86670480',
#  '87308348',
#  '85860649',
#  '79884021',
#  '66922127',
#  '88026002',
#  '87990330',
#  '87300151',
#  '87285857',
#  '86935692',
#  '86659751',
#  '87657389',
#  '86923060',
#  '86960146',
#  '87979987',
#  '87731055',
#  '86280717',
#  '87824712',
#  '87981270',
#  '87823501',
#  '88025011',
#  '87025580',
#  '87858943',
#  '86249162',
#  '79051303',
#  '87631743',
#  '86630480',
#  '86486022',
#  '86631659',
#  '46368256',
#  '87725559',
#  '86280638',
#  '87740739',
#  '87745000',
#  '87664194',
#  '87891433',
#  '86789503',
#  '87662685',
#  '86921601',
#  '86750620',
#  '86985667',
#  '88005529',
#  '87333451',
#  '86581736',
#  '87628205',
#  '86921406',
#  '87366468',
#  '87103112',
#  '82957200',
#  '86762938',
#  '87466781',
#  '87444386',
#  '79627413',
#  '85051950',
#  '87288752',
#  '87514312',
#  '87868937',
#  '86789538',
#  '82143109',
#  '86979717',
#  '87827011',
#  '86751685',
#  '86330829',
#  '87613060',
#  '86794610',
#  '86210128',
#  '82893736',
#  '87496866',
#  '88048388',
#  '87736444',
#  '86337450',
#  '87265440',
#  '87640463',
#  '87418410',
#  '83570628',
#  '87309200',
#  '86979720',
#  '78050082',
#  '87588179',
#  '84244467',
#  '87933342',
#  '87755022',
#  '87289366',
#  '87985705',
#  '87712700',
#  '87968645',
#  '82982085',
#  '87371472',
#  '87766530',
#  '87999053',
#  '85762670',
#  '87876117',
#  '87949959',
#  '87172582',
#  '87186142',
#  '87387587',
#  '86196022',
#  '82287114',
#  '87160716',
#  '86285186',
#  '87590843',
#  '87754673',
#  '84959738',
#  '85575274',
#  '87742786',
#  '86631896',
#  '87938120',
#  '87368474',
#  '87719782',
#  '86612974',
#  '87601865',
#  '86264355',
#  '87332166',
#  '86732083',
#  '86352061',
#  '86742468',
#  '87508495',
#  '86924366',
#  '87508346',
#  '87822939',
#  '86653844',
#  '86720535',
#  '87860318',
#  '85901598',
#  '86867732',
#  '84011315',
#  '87133218',
#  '87507948',
#  '85399328',
#  '86358277',
#  '86653263',
#  '85955598',
#  '87529846',
#  '86280749',
#  '80304104',
#  '87409812',
#  '80340878',
#  '87959345',
#  '87135968',
#  '87802363',
#  '86268657',
#  '88060088',
#  '86710312',
#  '87790955',
#  '86695182',
#  '87162738',
#  '87182175',
#  '86619396',
#  '86984774',
#  '68489073',
#  '88045419',
#  '87826244',
#  '87285514',
#  '87991764',
#  '85985299',
#  '88044914',
#  '87608990',
#  '87367257',
#  '84531709',
#  '86267491',
#  '86734219',
#  '88062132',
#  '87843072',
#  '87581034',
#  '87705642',
#  '85850906',
#  '87823429',
#  '54462736',
#  '87415602',
#  '86630167',
#  '77603056',
#  '87784238',
#  '86378465',
#  '87505621',
#  '87391638',
#  '86884490',
#  '86897651',
#  '87839347',
#  '87878412',
#  '86574703',
#  '87134513',
#  '87754681',
#  '87826243',
#  '87907134',
#  '86581735',
#  '87759152',
#  '85629479',
#  '81530771',
#  '87279544',
#  '87768655',
#  '76747159',
#  '86886802',
#  '87342769',
#  '87741095',
#  '86220784',
#  '86786927',
#  '87147383',
#  '87961344',
#  '86538388',
#  '87320388',
#  '87138593',
#  '67115536',
#  '86730151',
#  '87721152',
#  '86663785',
#  '86417268',
#  '87746995',
#  '84886644',
#  '87721587',
#  '86874820',
#  '87597834',
#  '87592653',
#  '86570701',
#  '85975111',
#  '87582101',
#  '87351479',
#  '87526349',
#  '87655408',
#  '87298185',
#  '87867388',
#  '72687478',
#  '87762877',
#  '87566551',
#  '87968635',
#  '87884805',
#  '82761773',
#  '87834253',
#  '86860276',
#  '87678199',
#  '87758718',
#  '87347604',
#  '87977986',
#  '86228698',
#  '84302064',
#  '87516890',
#  '87624988',
#  '87702430',
#  '85600062',
#  '85227201',
#  '87510401',
#  '87828370',
#  '86866085',
#  '88036616',
#  '83774073',
#  '86966317',
#  '86669932',
#  '87588339',
#  '87432494',
#  '87468100',
#  '69558405',
#  '86617104',
#  '87293127',
#  '87858982',
#  '88049215',
#  '87462338',
#  '88051447',
#  '87683219',
#  '86925478',
#  '87751890',
#  '87745889',
#  '87466261',
#  '87440700',
#  '87737912',
#  '87570169',
#  '86856508',
#  '86641266',
#  '87937435',
#  '87467577',
#  '86225384',
#  '85738677',
#  '86776294',
#  '87426839',
#  '86852326',
#  '87143042',
#  '87847152',
#  '87582066',
#  '83080777',
#  '88062187',
#  '86787140',
#  '86739787',
#  '87206049',
#  '87727638',
#  '86631227',
#  '87774774',
#  '87723311',
#  '86843468',
#  '87003483',
#  '87990014',
#  '87490464',
#  '86309741',
#  '85830928',
#  '88015815',
#  '87279152',
#  '87909431',
#  '77697001',
#  '88010188',
#  '87110466',
#  '83928076',
#  '87300128',
#  '85043813',
#  '86435975',
#  '86603818',
#  '86284309',
#  '88062510',
#  '87845441',
#  '83635533',
#  '86706176',
#  '86866672',
#  '87899790',
#  '88026872',
#  '87769972',
#  '88020805',
#  '87156006',
#  '86444669',
#  '87819753',
#  '86396022',
#  '84756985',
#  '87416360',
#  '86675965',
#  '86028852',
#  '82742802',
#  '87580260',
#  '30548119',
#  '78157311',
#  '86548323',
#  '87856537',
#  '87916570',
#  '73454226',
#  '87154363',
#  '86663812',
#  '85471058',
#  '78138858',
#  '76478359',
#  '87622837',
#  '85726481',
#  '87936110',
#  '87699511',
#  '87263602',
#  '85612766',
#  '87295798',
#  '87878940',
#  '87822271',
#  '87892751',
#  '84511634',
#  '87532235',
#  '88041406',
#  '87274800',
#  '86610870',
#  '87860380',
#  '87277541',
#  '87499190',
#  '85107493',
#  '87781408',
#  '87709592',
#  '86870291',
#  '87737409',
#  '86667389',
#  '87584903',
#  '87959802',
#  '87489535',
#  '86810277',
#  '87714821',
#  '79464839',
#  '87833619',
#  '86852958',
#  '83352971',
#  '84854267',
#  '87929081',
#  '87457391',
#  '87222657',
#  '86590469',
#  '77427564',
#  '87864454',
#  '87391271',
#  '87162168',
#  '87512896',
#  '82613417',
#  '86974188',
#  '88015811',
#  '88007327',
#  '87490886',
#  '86989205',
#  '87664103',
#  '86687428',
#  '87745762',
#  '87252931',
#  '86676884',
#  '87398134',
#  '82786167',
#  '80766622',
#  '85935508',
#  '87379965',
#  '82992094',
#  '87944405',
#  '87445542',
#  '86982124',
#  '87891572',
#  '87640101',
#  '86187885',
#  '86651664',
#  '86513113',
#  '85890317',
#  '77752091',
#  '87004041',
#  '87241628',
#  '87507923',
#  '84081902',
#  '84819562',
#  '87163497',
#  '83923906',
#  '86674287',
#  '87653708',
#  '87688836',
#  '87786809',
#  '87798198',
#  '86884667',
#  '88047880',
#  '87648934',
#  '87733705',
#  '87409890',
#  '86718022',
#  '86732096',
#  '81359652',
#  '87529052',
#  '82509167',
#  '85679455',
#  '87535158',
#  '87218604',
#  '86972338',
#  '87026248',
#  '87974288',
#  '78412670',
#  '84428837',
#  '86011662',
#  '88001866',
#  '87914225',
#  '87160449',
#  '87656512',
#  '87269950',
#  '87611871',
#  '87376941',
#  '87718626',
#  '86675227',
#  '86548472',
#  '86173322',
#  '87994663',
#  '84065849',
#  '85927960',
#  '87734988',
#  '87184239',
#  ...}

# %%
vacancies = {}

# %%
ids_to_fetch = ids.copy()
async with aiohttp.ClientSession() as session:
    while len(ids_to_fetch):
        ok_ids = {k for k, v in vacancies.items() if 'id' in v.keys()}
        ids_to_fetch -= ok_ids
        print(f'Ok is {len(ok_ids)}.\t To fetch is {len(ids_to_fetch)}')

        tasks = []
        for id in ids_to_fetch:
            url = f'https://api.hh.ru/vacancies/{id}'
            payload = {}
            tasks.append(fetch(session, url, payload, vacancies, id))
        await sema(7, tasks)
# Out:
# Ok is 2000.	 To fetch is 0

# %% [markdown]
# 5 + 7 + 4 + 2 = <18

# %%
list(vacancies.values())[0]
# Out:
# {'id': '87994663',
#  'premium': False,
#  'billing_type': {'id': 'standard', 'name': 'Стандарт'},
#  'relations': [],
#  'name': 'Data Engineer',
#  'insider_interview': None,
#  'response_letter_required': False,
#  'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#  'salary': {'from': 2000, 'to': 4000, 'currency': 'USD', 'gross': False},
#  'type': {'id': 'open', 'name': 'Открытая'},
#  'address': None,
#  'allow_messages': True,
#  'experience': {'id': 'between3And6', 'name': 'От 3 до 6 лет'},
#  'schedule': {'id': 'remote', 'name': 'Удаленная работа'},
#  'employment': {'id': 'full', 'name': 'Полная занятость'},
#  'department': None,
#  'contacts': None,
#  'description': '<p><strong>Внимание, кандидатов с опытом работы менее 3-х лет просьба не оставлять откликов!</strong></p> <p><strong>Чем предстоит заниматься:</strong></p> <ul> <li>Продуктивизация и поддержка моделей данных;</li> <li>Создание пайплайнов обработки данных: собирать датасеты из существующих источников данных, запускать модели и доставлять их результат до конечного бизнес-заказчика;</li> <li>Добавление в пайплайн data quality мониторинга и увеличение производительности существующих моделей;</li> <li>Построение архитектуры;</li> </ul> <p><strong>Главные требования:</strong></p> <ul> <li>Опыт реализации, масштабирования, поддержки, интеграции высокогонагруженных сервисов, внутри которых жили построенные Data Scientist’ами алгоритмы и ML-модели;</li> <li>Знание концепций баз данных и программирования;</li> <li>Структурное мышление и умение излагать свои мысли;</li> <li>Опыт работы в электронной коммерции будет плюсом;</li> </ul> <p><strong>Стек</strong></p> <ol> <li><strong>разработка:</strong> Python 3.10, GitLab, Docker, Kubernetes, Java, typescript, php;</li> <li><strong>данные:</strong> PostgreSQL, Kafka; MySQL;</li> <li><strong>отчеты и мониторинги:</strong> Prometheus, Grafana;</li> </ol> <p><strong>Условия:</strong></p> <ul> <li>Удаленная работа;</li> <li>Большая и крутая команда разработчиков;</li> <li>Своевременная выплата заработной платы;</li> <li>Работа над интересным проектом;</li> </ul> <p> </p>',
#  'branded_description': None,
#  'vacancy_constructor_template': None,
#  'key_skills': [{'name': 'Python'},
#   {'name': 'GitLab'},
#   {'name': 'Docker'},
#   {'name': 'Kubernetes'},
#   {'name': 'Java'},
#   {'name': 'PHP'},
#   {'name': 'typescript'},
#   {'name': 'PostgreSQL'},
#   {'name': 'MySQL'}],
#  'accept_handicapped': False,
#  'accept_kids': False,
#  'archived': False,
#  'response_url': None,
#  'specializations': [],
#  'professional_roles': [{'id': '40', 'name': 'Другое'}],
#  'code': None,
#  'hidden': False,
#  'quick_responses_allowed': False,
#  'driver_license_types': [],
#  'accept_incomplete_resumes': False,
#  'employer': {'id': '5709044',
#   'name': 'Андреев Александр Вячеславович',
#   'url': 'https://api.hh.ru/employers/5709044',
#   'alternate_url': 'https://hh.ru/employer/5709044',
#   'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/6070594.jpeg',
#    '90': 'https://hhcdn.ru/employer-logo/6070593.jpeg',
#    'original': 'https://hhcdn.ru/employer-logo-original/1112498.jpeg'},
#   'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=5709044',
#   'accredited_it_employer': False,
#   'trusted': True},
#  'published_at': '2023-10-10T16:00:35+0300',
#  'created_at': '2023-10-10T16:00:35+0300',
#  'initial_created_at': '2023-10-10T16:00:35+0300',
#  'negotiations_url': None,
#  'suitable_resumes_url': None,
#  'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=87994663',
#  'has_test': False,
#  'test': None,
#  'alternate_url': 'https://hh.ru/vacancy/87994663',
#  'working_days': [],
#  'working_time_intervals': [],
#  'working_time_modes': [],
#  'accept_temporary': True,
#  'languages': []}

# %%
all(x['description'] for x in vacancies.values())
# Out:
# True

# %%
path = '../storage/vacancies_2k_.pkl'

# with open(path, 'wb') as f:
#     pickle.dump(vacancies, f)

# with open(path, 'rb') as f:
#     vacancies = pickle.load(f)

# %%
corpus = [x['description'] for x in vacancies.values()]

# %%
corpus[:5]
# Out:
# ['<p><strong>Внимание, кандидатов с опытом работы менее 3-х лет просьба не оставлять откликов!</strong></p> <p><strong>Чем предстоит заниматься:</strong></p> <ul> <li>Продуктивизация и поддержка моделей данных;</li> <li>Создание пайплайнов обработки данных: собирать датасеты из существующих источников данных, запускать модели и доставлять их результат до конечного бизнес-заказчика;</li> <li>Добавление в пайплайн data quality мониторинга и увеличение производительности существующих моделей;</li> <li>Построение архитектуры;</li> </ul> <p><strong>Главные требования:</strong></p> <ul> <li>Опыт реализации, масштабирования, поддержки, интеграции высокогонагруженных сервисов, внутри которых жили построенные Data Scientist’ами алгоритмы и ML-модели;</li> <li>Знание концепций баз данных и программирования;</li> <li>Структурное мышление и умение излагать свои мысли;</li> <li>Опыт работы в электронной коммерции будет плюсом;</li> </ul> <p><strong>Стек</strong></p> <ol> <li><strong>разработка:</strong> Python 3.10, GitLab, Docker, Kubernetes, Java, typescript, php;</li> <li><strong>данные:</strong> PostgreSQL, Kafka; MySQL;</li> <li><strong>отчеты и мониторинги:</strong> Prometheus, Grafana;</li> </ol> <p><strong>Условия:</strong></p> <ul> <li>Удаленная работа;</li> <li>Большая и крутая команда разработчиков;</li> <li>Своевременная выплата заработной платы;</li> <li>Работа над интересным проектом;</li> </ul> <p> </p>',
#  '<p> </p> <p>Ищем инженера-программиста для разработки клиентских десктопных C++ приложений с Qt QML графическим интерфейсом. А также - развития и доработки серверной части этих приложений. Целевые плантформы - windows/linux.</p> <p><strong>Основные требования:</strong></p> <ul> <li>Опыт коммерческой разработки от 2 лет;</li> <li>Уверенное знание С++11 или выше;</li> <li>Знание алгоритмов и структур данных;</li> <li>Знание Qt;</li> <li>Знания и опыт в области сетевого взаимодействия;</li> <li>Знания и опыт в области работы с базами данных.</li> </ul> <p><strong>Будет плюсом:</strong></p> <ul> <li>Знание qml;</li> <li>Знание boost;</li> <li>Базовые знания linux/windows(на уровне командной строки), либо python;</li> <li>Понимание механизмов и опыт в области CI/СD.</li> </ul> <p><strong>Обязанности:</strong></p> <ul> <li>Создание desktop приложений (C++, Qt, QML);</li> <li>Участие в разработке библиотек;</li> <li>Участие в настройке CI/CD.</li> </ul> <p><strong>Мы предлагаем:</strong></p> <ul> <li>Официальное трудоустройство;</li> <li>&quot;Белую заработную плату&quot; (уровень заработной платы с успешным кандидатом обсуждается индивидуально на собеседовании), премии по результатам проектов, &quot;13-я заработная плата&quot; в конце календарного года ;</li> <li>Молодой дружный коллектив;</li> <li>Обучение за счет компании;</li> <li>Перспективу карьерного роста;</li> <li>ДМС по окончании испытательного срока;</li> <li>Корпоративный досуг (спортивные секции, походы в театр, квизы и т.д.).</li> </ul>',
#  '<p><strong>Описание вакансии:</strong></p> <p>В отдел разработки автоматизированных систем управления;<br />(ул. Масленникова, 231) требуется <strong>сетевой инженер </strong><br /><strong>в проект <strong>разработки автоматизированной системы управления связью.</strong></strong></p> <p>Удаленный формат работы исключается - нам важно ваше присутствие на рабочем месте!</p> <p><strong>Функциональные обязанности</strong></p> <p>- Настройка сетевого оборудования (Juniper, Huawei, Eltex, D-Link, Cisco)<br />- Диагностика и устранение проблем в сети<br />- Построение и отладка решений в EVE-NG<br />- Написание документации и сетевых диаграмм<br />- Взаимодействие с командой разработки</p> <p><strong>Требования</strong>:</p> <p>- Опыт работы сетевым инженером от 3 лет<br />- Опыт работы по дизайну, внедрению, тестированию и исправлению сетевых топологий, в которых используются L2(VLAN, RSTP, LinkAggregation), L3(BGP, OSPF, EIGRP), IPSec, SSL, GRE протоколы.<br />- Опыт работы с инструментами анализа и мониторинга сетей<br />- Python будет плюсом</p> <p><strong>Мы предлагаем:</strong></p> <ul> <li>Только официальное трудоустройство по ТК РФ, стабильная заработная плата.</li> <li>5-дневная рабочая неделя, 8-часовой рабочий день. Удаленная форма не предусмотрена, нам важно ваше присутствие на рабочем месте.</li> <li>Расширенный социальный пакет в соответствии с коллективным договором.</li> <li><strong>Отсрочка от призыва</strong> в соответствии с Постановлением Правительства РФ.</li> <li>Широкие возможности для профессионального развития, карьерного и зарплатного роста.</li> </ul> <p><strong>Уровень оплаты труда определяется индивидуально по итогам собеседования.</strong></p>',
#  '<p><strong>Обязанности:</strong></p> <ul> <li>Разработка web-приложений;</li> <li>Участие в обсуждении и проработке концепций и нового функционала;</li> <li>Участие в построении архитектуры и проектировании;</li> <li>Взаимодействие со стажерами (Студенты Алабуга-Политех).</li> </ul> <strong>Требования:</strong> <ul> <li>Хорошие знания Python 3.*</li> <li>Опыт работы с Django/Sanic/Tornado/FastApi</li> <li>Опыт работы с Asyncio</li> <li>Опыт работы с Websocket</li> <li>Опыт работы с Pydantic</li> <li>Опыт работы с Docker</li> <li>Опыт работы с Git</li> <li>Уверенные знания REST</li> <li>Опыт работы с реляционными базами данных (PostgreSQL, MySQL)</li> <li>Уровень «уверенный Middle»</li> </ul> <p> </p> <strong>Условия:</strong> <ul> <li>дневная рабочая неделя 5/2, с 8:00 до 17:00 (ненормированная);</li> <li>формат работы - офис;</li> <li>работа в крупной и стабильной компании – в структуре самой большой ОЭЗ в Европе;</li> <li>транспорт до работы из г. Елабуга, г. Набережные Челны, г. Менделеевск;</li> <li>оплачиваемые отпуска и больничные;</li> <li>гарантия профессионального роста, бесплатное обучение;</li> <li>молодую, амбициозную, проектно-ориентированную команду;</li> <li>командные игры, мозговые штурмы, реализация нестандартных задач;</li> <li>карьерный рост при наличии и обретения в процессе работы необходимых компетенций;</li> <li>заработная плата по результатам собеседовании.</li> </ul> <p> </p>',
#  '<p><strong>О проекте:</strong></p> <p>Компания С&amp;C Labs — итог многолетней деятельности нашей команды по исследованию финансовых рынков. У истоков проекта: широко известный в узких кругах эксперт по торговым стратегиям и основатель популярного криптокомьюнити, архангел Бинанса, TPM Амазона и другие хорошие люди. Мы разработали принципиально новую автоматизированную торговую систему и набираем фулл-тайм команду для доработки и обновлений продукта.</p> <p><strong>Требования:</strong></p> <ul> <li>Опыт работы в роли DevOps Engineer от 2 лет;</li> <li>Опыт работы с Docker + Docker-Compose + Docker Swarm;</li> <li>Опыт конфигурирования, управления и шардирования PostgreSQL, MongoDB/Mongo Atlas;</li> <li>Знание облачных провайдеров: AWS, Digital Ocean; настройка и подключение Load Balancer инфраструктуры;</li> <li>Знание Linux, Git/Github.</li> </ul> <p><strong>Будет плюсом:</strong></p> <ul> <li>Опыт работы с Celery;</li> <li>GitHub Actions;</li> <li>Grafana + Prometheus;</li> <li>Kubernetes;</li> <li>ELK.</li> </ul> <p><strong>Условия:</strong></p> <ul> <li>Оформление по контракту</li> <li>Гибкий график</li> <li>Полностью удаленная работа</li> <li>Отсутствие бюрократии и сложных долгих согласований</li> <li>Возможность предлагать, разрабатывать и внедрять вместе с командой собственные технические решения</li> </ul>']

# %%
def apply_re(pattern: str, reply_on: str, corpus: t.Sequence[str]) -> t.MutableSequence[str]:
    return list(map(lambda x: re.sub(pattern, reply_on, x), corpus))

# %%
corpus = apply_re('(<[^>]+>|\s)', ' ', corpus)
corpus = apply_re('[^{а-яА-Яa-zA-Z0-9}]', ' ', corpus)
corpus = apply_re('\s+', ' ', corpus)

corpus[:10]
# Out:
# [' Внимание кандидатов с опытом работы менее 3 х лет просьба не оставлять откликов Чем предстоит заниматься Продуктивизация и поддержка моделей данных Создание пайплайнов обработки данных собирать датасеты из существующих источников данных запускать модели и доставлять их результат до конечного бизнес заказчика Добавление в пайплайн data quality мониторинга и увеличение производительности существующих моделей Построение архитектуры Главные требования Опыт реализации масштабирования поддержки интеграции высокогонагруженных сервисов внутри которых жили построенные Data Scientist ами алгоритмы и ML модели Знание концепций баз данных и программирования Структурное мышление и умение излагать свои мысли Опыт работы в электронной коммерции будет плюсом Стек разработка Python 3 10 GitLab Docker Kubernetes Java typescript php данные PostgreSQL Kafka MySQL отчеты и мониторинги Prometheus Grafana Условия Удаленная работа Большая и крутая команда разработчиков Своевременная выплата заработной платы Работа над интересным проектом ',
#  ' Ищем инженера программиста для разработки клиентских десктопных C приложений с Qt QML графическим интерфейсом А также развития и доработки серверной части этих приложений Целевые плантформы windows linux Основные требования Опыт коммерческой разработки от 2 лет Уверенное знание С 11 или выше Знание алгоритмов и структур данных Знание Qt Знания и опыт в области сетевого взаимодействия Знания и опыт в области работы с базами данных Будет плюсом Знание qml Знание boost Базовые знания linux windows на уровне командной строки либо python Понимание механизмов и опыт в области CI СD Обязанности Создание desktop приложений C Qt QML Участие в разработке библиотек Участие в настройке CI CD Мы предлагаем Официальное трудоустройство quot Белую заработную плату quot уровень заработной платы с успешным кандидатом обсуждается индивидуально на собеседовании премии по результатам проектов quot 13 я заработная плата quot в конце календарного года Молодой дружный коллектив Обучение за счет компании Перспективу карьерного роста ДМС по окончании испытательного срока Корпоративный досуг спортивные секции походы в театр квизы и т д ',
#  ' Описание вакансии В отдел разработки автоматизированных систем управления ул Масленникова 231 требуется сетевой инженер в проект разработки автоматизированной системы управления связью Удаленный формат работы исключается нам важно ваше присутствие на рабочем месте Функциональные обязанности Настройка сетевого оборудования Juniper Huawei Eltex D Link Cisco Диагностика и устранение проблем в сети Построение и отладка решений в EVE NG Написание документации и сетевых диаграмм Взаимодействие с командой разработки Требования Опыт работы сетевым инженером от 3 лет Опыт работы по дизайну внедрению тестированию и исправлению сетевых топологий в которых используются L2 VLAN RSTP LinkAggregation L3 BGP OSPF EIGRP IPSec SSL GRE протоколы Опыт работы с инструментами анализа и мониторинга сетей Python будет плюсом Мы предлагаем Только официальное трудоустройство по ТК РФ стабильная заработная плата 5 дневная рабочая неделя 8 часовой рабочий день Удаленная форма не предусмотрена нам важно ваше присутствие на рабочем месте Расширенный социальный пакет в соответствии с коллективным договором Отсрочка от призыва в соответствии с Постановлением Правительства РФ Широкие возможности для профессионального развития карьерного и зарплатного роста Уровень оплаты труда определяется индивидуально по итогам собеседования ',
#  ' Обязанности Разработка web приложений Участие в обсуждении и проработке концепций и нового функционала Участие в построении архитектуры и проектировании Взаимодействие со стажерами Студенты Алабуга Политех Требования Хорошие знания Python 3 Опыт работы с Django Sanic Tornado FastApi Опыт работы с Asyncio Опыт работы с Websocket Опыт работы с Pydantic Опыт работы с Docker Опыт работы с Git Уверенные знания REST Опыт работы с реляционными базами данных PostgreSQL MySQL Уровень уверенный Middle Условия дневная рабочая неделя 5 2 с 8 00 до 17 00 ненормированная формат работы офис работа в крупной и стабильной компании в структуре самой большой ОЭЗ в Европе транспорт до работы из г Елабуга г Набережные Челны г Менделеевск оплачиваемые отпуска и больничные гарантия профессионального роста бесплатное обучение молодую амбициозную проектно ориентированную команду командные игры мозговые штурмы реализация нестандартных задач карьерный рост при наличии и обретения в процессе работы необходимых компетенций заработная плата по результатам собеседовании ',
#  ' О проекте Компания С amp C Labs итог многолетней деятельности нашей команды по исследованию финансовых рынков У истоков проекта широко известный в узких кругах эксперт по торговым стратегиям и основатель популярного криптокомьюнити архангел Бинанса TPM Амазона и другие хорошие люди Мы разработали принципиально новую автоматизированную торговую систему и набираем фулл тайм команду для доработки и обновлений продукта Требования Опыт работы в роли DevOps Engineer от 2 лет Опыт работы с Docker Docker Compose Docker Swarm Опыт конфигурирования управления и шардирования PostgreSQL MongoDB Mongo Atlas Знание облачных провайдеров AWS Digital Ocean настройка и подключение Load Balancer инфраструктуры Знание Linux Git Github Будет плюсом Опыт работы с Celery GitHub Actions Grafana Prometheus Kubernetes ELK Условия Оформление по контракту Гибкий график Полностью удаленная работа Отсутствие бюрократии и сложных долгих согласований Возможность предлагать разрабатывать и внедрять вместе с командой собственные технические решения ',
#  ' Обязанности Портирование или написание драйверов устройств для ОС Linux Участие в разработке программной и аппаратной части нового планшетного навигационного устройства Поддержка и модернизация программной части существующего парка планшетных устройств Написание технической документации Профессиональные навыки Желателен опыт разработки модулей ядра linux Опыт разработки под разные аппаратные платформы Работа с системой контроля исходного кода GIT Средства сборки и отладки GCC Make CMake GDB Valgrind Опыт работы в команде умение быстро разбираться в чужом коде Приветствуется знание фреймворка Qt языка программирования Python Условия Оформление по ТК РФ График работы 5 2 Частичная компенсация питания в столовой Возможен карьерный рост ДМС ',
#  ' В нашу дружную команду из 11 PHP разработчиков laravel symfony мы ищем ведущего PHP разработчика и просто хорошего человека В команде будет 6 разработчиков Наш будущий коллега это уверенный PHP разработчик выполняющий у нас функции разработчика с задачами ресурсного менеджера Если такие задачи не интересны мы готовы рассмотреть на роль разработчика без развития коллег Основные задачи Писать чистый и рабочий код для проектов компании примерно половина рабочего времени разработка Проведение код ревью контроль качества задач Распределение задач помощь с их декомпозицией принятие архитектурных решений Организация работы команды и развитие направления PHP разработки контроль ворклогов проведение one to one составление ИПР Какой опыт нужен Опыт работы от 2 х лет на любом из фреймворков yii2 laravel symfony Хорошие тех скиллы на уровне от миддла и выше SQL git composer php stan codesnifer redis rabbit mq REST API SOAP и т д Опыт в роли лида или ментора наставника Высокий уровень софтов для эффективной коммуникации с командой Мы предлагаем Заработная плата зависит от твоего предыдущего опыта вилка на входе до 200 000 нетто Формат удаленка OR офис Ульяновск OR Краснодар Душевный и простой коллектив минимум бюрократии Оформление по ТК ИП и самозанятость не рассматриваем Пересмотры оклада на основании ИПР или PerformanceReview ДМС Разнообразные активности даже для удал нщиков Гибкий график без секунданта и объяснительных Немного о нас Работаем с самыми известными брендами России и мира Всемирный фонд дикой природы WWF Яндекс Авито Сбербанк Ашан страховая компания Согласие УралХим ВторПлюс Рольф и еще десятки клиентов Мы разрабатываем решения Soft Web Mobile ML AI которыми пользуются миллионы людей в России и мире ваши друзья и близкие Наш стек PHP Python Java Go JS Kotlin Swift Строим компанию с человеческим лицом даем людям свободу с пониманием относимся к их желаниями Уже более 200 человек доверяют нам свое будущее Интересно Пиши и обсудим детали ',
#  ' INGA technology команда профессионалов работающая над разработкой решений в сфере искусственного интеллекта которую проивестировали американские фонды в 2019 году Приглашает на работу опытных веб разработчиков от уровня middle INGA technology является одним из проектов нашего медиа холдинга с успешной 12 летней историей и направлениями деятельности Трафиковые сайты Суммарная ежемесячная аудитория наших сайтов более 200 млн человек из 40 стран мира Являемся стратегическим партнером Google AdSense более 10 лет ИИ Исследовательская лаборатория в сфере обработки естественного языка NLP Проинвестирована американскими фондами Направлению больше 4 лет Более 3 млн потрачено только на GPU Блокчейн Именно и только в технологическом разрезе распределенных реестров Без ICO и токенов В крипте с 2014 года Майнили еще на видеокартах Сайдчейн и ончейн решения Инвестиции В портфеле имеются успешные play2earn игры крипто академия стейкинг ходл трейдинг В данный момент запустили новое направление внутри холдинга торговая платформа нового поколения Zero trust архитектура в связке с новым языком программирования на базе AI AI text based trading platform Под это новое направление и ищем опытных разработчиков Наши офисы находятся в Сан Франциско Барселона Лондон Дубай Москва Техническая команда состоит строго из профессионалов Никаких джунов и мелких скучных задач Несмотря на свой возраст сохранили корпоративную культуру и дух стартапа это вовсе не значит что мы работаем на выходных и сверхурочно наоборот у нас это строго запрещено мы бежим марафоны на длинные дистанции а не красноглазые стометровки в поисках инвестиций Дух стартапа в нашем понимании это отсутствие бюрократии и поиск нестандартных решений в условиях недостаточности информации Наш бессменный генеральный директор и основатель холдинга программист с 20 летним стажем enterprise highload разработки Твои знания и умения Node js ES6 тесты Mocha Chai Jasmine Jest ORM и нативный MySQL написание сложных SQL запросов проектирование эффективной реляционных БД оптимизация транзакции PHP ORM один из фреймворков Zend Laravel Yii Symfony HTML CSS Командную строку nix git apache nginx Опыт работы с С C Rust Go Python Clojure ФП Sphinx Memcache RabbitMQ Redis Docker WebRTC ElasticSearch Что мы хотим увидеть в тебе Высшее техническое образование Опыт работы от 5 лет Умение искать и находить нестандартные решения Опыт работы с системами непрерывной интеграции Мы предлагаем Достойная заработная плата Профессиональный коллектив Полная занятость удаленная работа Адаптивное оформление самозанятые ИП и другие варианты Неограниченные возможности для профессионального роста поддержку в развитии и обучении Отсутствие бюрократии простая и прозрачная схема работы Широкий спектр интересных задач Возможность прокачать свои навыки Новые и востребованные технологии ',
#  ' Работа в крупном стабильном Банке интересные задачи по разработке ПО в рамках новых масштабных проектов Обязанности Участие в разработке новых и сопровождении существующих модулей корпоративной информационной системы Требования Высшее профильное образование обязательно хорошая подготовка в области разработки программного обеспечения опыт работы в должности отличное знание любого из современных языков программирования Java C Python C и т п уверенное владение объектно ориентированным подходом к разработке ПО знакомство с шаблонами проектирования понимание чем хороший код отличается от плохого умение тестировать собственный код знание технического английского языка хорошие навыки написания программ для современных реляционных СУБД серверов приложений web серверов многопоточных приложений умение и желание самостоятельно решать поставленные задачи Условия Сильная команда профессионалов Программа наставничества Официальное трудоустройство ДМС Премирование сотрудников Банка ежемесячное и дополнительное Пятидневная рабочая неделя с 08 00 до 17 00 Возможность работать удал нно после прохождения испытательного срока Комфортные условия труда рабочее место в центре города Премирование сотрудников Банка ежемесячное и дополнительное Расширенный социальный пакет бесплатное медицинское обслуживание сотрудников в медицинской службе предприятия организация питания сотрудников по льготным ценам в корпоративной столовой дополнительные оплачиваемые дни отпуска материальная поддержка сотрудников организация корпоративных мероприятий к праздникам подарки сотрудникам и их детям финансирование спортивных и культурных мероприятий коллективное посещение бассейна спортзала театра кино частичная компенсация стоимости путевок в детские оздоровительные и спортивные лагеря присвоение почетных званий и памятных знаков с выделением материального поощрения в связи с награждением сотрудников ',
#  ' ReSpec это передовая система видеоаналитики разработанная с целью обеспечить эффективное управление вашим бизнесом независимо от его сферы деятельности Она предлагает широкий спектр инструментов и функциональных возможностей основанных на анализе видеоданных чтобы помочь вам принимать осознанные решения повышать эффективность операций и повышать безопасность Задачи которыми предстоит заниматься Разрабатывать алгоритмы детекции сегментации классификации и трекинга Исследовать и анализировать существующие подходы в видеоаналитики и обработке изображений Обучать тестировать адаптировать и ускорять инференс моделей компьютерного зрения Участие в разработке высоконагруженных сервисов Что для нас важно Хорошие знания Python и умение писать на нем качественный и понятный код Знание классического ML классификация кластеризация регрессия Понимание фреймворков по глубокому изучению Знание ultralytics Yolov8 Опыт работы с OpenCV Что мы предлагаем Удал нка офис Королев Заинтересованных коллег готовых оказать поддержку Душевный и простой коллектив минимум бюрократии Оформление по ТК пересмотры оклада премии Гибкий график ']

# %%
morph = MorphAnalyzer()
stop_words = stopwords.words('russian')

corpus = [
    [
        word_norm for word in word_tokenize(doc, language='russian')
        if (word_norm := morph.normal_forms(word)[0]) not in stop_words
    ] for doc in corpus
]

corpus[:5]
# Out:
# [['внимание',
#   'кандидат',
#   'опыт',
#   'работа',
#   'менее',
#   '3',
#   'х',
#   'год',
#   'просьба',
#   'оставлять',
#   'отклик',
#   'предстоять',
#   'заниматься',
#   'продуктивизация',
#   'поддержка',
#   'модель',
#   'данные',
#   'создание',
#   'пайплайн',
#   'обработка',
#   'данные',
#   'собирать',
#   'датасет',
#   'существующий',
#   'источник',
#   'данные',
#   'запускать',
#   'модель',
#   'доставлять',
#   'результат',
#   'конечный',
#   'бизнес',
#   'заказчик',
#   'добавление',
#   'пайплайна',
#   'data',
#   'quality',
#   'мониторинг',
#   'увеличение',
#   'производительность',
#   'существующий',
#   'модель',
#   'построение',
#   'архитектура',
#   'главный',
#   'требование',
#   'опыт',
#   'реализация',
#   'масштабирование',
#   'поддержка',
#   'интеграция',
#   'высокогонагруженный',
#   'сервис',
#   'внутри',
#   'который',
#   'жить',
#   'построить',
#   'data',
#   'scientist',
#   'ами',
#   'алгоритм',
#   'ml',
#   'модель',
#   'знание',
#   'концепция',
#   'база',
#   'данные',
#   'программирование',
#   'структурный',
#   'мышление',
#   'умение',
#   'излагать',
#   'свой',
#   'мысль',
#   'опыт',
#   'работа',
#   'электронный',
#   'коммерция',
#   'плюс',
#   'стек',
#   'разработка',
#   'python',
#   '3',
#   '10',
#   'gitlab',
#   'docker',
#   'kubernetes',
#   'java',
#   'typescript',
#   'php',
#   'дать',
#   'postgresql',
#   'kafka',
#   'mysql',
#   'отчёт',
#   'мониторинг',
#   'prometheus',
#   'grafana',
#   'условие',
#   'удалённый',
#   'работа',
#   'больший',
#   'крутой',
#   'команда',
#   'разработчик',
#   'своевременный',
#   'выплата',
#   'заработный',
#   'плата',
#   'работа',
#   'интересный',
#   'проект'],
#  ['искать',
#   'инженер',
#   'программист',
#   'разработка',
#   'клиентский',
#   'десктопный',
#   'c',
#   'приложение',
#   'qt',
#   'qml',
#   'графический',
#   'интерфейс',
#   'также',
#   'развитие',
#   'доработка',
#   'серверный',
#   'часть',
#   'приложение',
#   'целевой',
#   'плантформа',
#   'windows',
#   'linux',
#   'основной',
#   'требование',
#   'опыт',
#   'коммерческий',
#   'разработка',
#   '2',
#   'год',
#   'уверенный',
#   'знание',
#   '11',
#   'выше',
#   'знание',
#   'алгоритм',
#   'структура',
#   'данные',
#   'знание',
#   'qt',
#   'знание',
#   'опыт',
#   'область',
#   'сетевой',
#   'взаимодействие',
#   'знание',
#   'опыт',
#   'область',
#   'работа',
#   'база',
#   'данные',
#   'плюс',
#   'знание',
#   'qml',
#   'знание',
#   'boost',
#   'базовый',
#   'знание',
#   'linux',
#   'windows',
#   'уровень',
#   'командный',
#   'строка',
#   'либо',
#   'python',
#   'понимание',
#   'механизм',
#   'опыт',
#   'область',
#   'ci',
#   'сd',
#   'обязанность',
#   'создание',
#   'desktop',
#   'приложение',
#   'c',
#   'qt',
#   'qml',
#   'участие',
#   'разработка',
#   'библиотека',
#   'участие',
#   'настройка',
#   'ci',
#   'cd',
#   'предлагать',
#   'официальный',
#   'трудоустройство',
#   'quot',
#   'белый',
#   'заработный',
#   'плата',
#   'quot',
#   'уровень',
#   'заработный',
#   'плата',
#   'успешный',
#   'кандидат',
#   'обсуждаться',
#   'индивидуально',
#   'собеседование',
#   'премия',
#   'результат',
#   'проект',
#   'quot',
#   '13',
#   'заработный',
#   'плата',
#   'quot',
#   'конец',
#   'календарный',
#   'год',
#   'молодой',
#   'дружный',
#   'коллектив',
#   'обучение',
#   'счёт',
#   'компания',
#   'перспектива',
#   'карьерный',
#   'рост',
#   'дмс',
#   'окончание',
#   'испытательный',
#   'срок',
#   'корпоративный',
#   'досуг',
#   'спортивный',
#   'секция',
#   'поход',
#   'театр',
#   'квиза',
#   'далее'],
#  ['описание',
#   'вакансия',
#   'отдел',
#   'разработка',
#   'автоматизированный',
#   'система',
#   'управление',
#   'ул',
#   'масленников',
#   '231',
#   'требоваться',
#   'сетевой',
#   'инженер',
#   'проект',
#   'разработка',
#   'автоматизированный',
#   'система',
#   'управление',
#   'связь',
#   'удалённый',
#   'формат',
#   'работа',
#   'исключаться',
#   'важно',
#   'ваш',
#   'присутствие',
#   'рабочий',
#   'место',
#   'функциональный',
#   'обязанность',
#   'настройка',
#   'сетевой',
#   'оборудование',
#   'juniper',
#   'huawei',
#   'eltex',
#   'd',
#   'link',
#   'cisco',
#   'диагностика',
#   'устранение',
#   'проблема',
#   'сеть',
#   'построение',
#   'отладка',
#   'решение',
#   'eve',
#   'ng',
#   'написание',
#   'документация',
#   'сетевой',
#   'диаграмма',
#   'взаимодействие',
#   'команда',
#   'разработка',
#   'требование',
#   'опыт',
#   'работа',
#   'сетевой',
#   'инженер',
#   '3',
#   'год',
#   'опыт',
#   'работа',
#   'дизайн',
#   'внедрение',
#   'тестирование',
#   'исправление',
#   'сетевой',
#   'топология',
#   'который',
#   'использоваться',
#   'l2',
#   'vlan',
#   'rstp',
#   'linkaggregation',
#   'l3',
#   'bgp',
#   'ospf',
#   'eigrp',
#   'ipsec',
#   'ssl',
#   'gre',
#   'протокол',
#   'опыт',
#   'работа',
#   'инструмент',
#   'анализ',
#   'мониторинг',
#   'сеть',
#   'python',
#   'плюс',
#   'предлагать',
#   'официальный',
#   'трудоустройство',
#   'тк',
#   'рф',
#   'стабильный',
#   'заработный',
#   'плата',
#   '5',
#   'дневный',
#   'рабочий',
#   'неделя',
#   '8',
#   'часовой',
#   'рабочий',
#   'день',
#   'удалённый',
#   'форма',
#   'предусмотреть',
#   'важно',
#   'ваш',
#   'присутствие',
#   'рабочий',
#   'место',
#   'расширить',
#   'социальный',
#   'пакет',
#   'соответствие',
#   'коллективный',
#   'договор',
#   'отсрочка',
#   'призыв',
#   'соответствие',
#   'постановление',
#   'правительство',
#   'рф',
#   'широкий',
#   'возможность',
#   'профессиональный',
#   'развитие',
#   'карьерный',
#   'зарплатный',
#   'рост',
#   'уровень',
#   'оплата',
#   'труд',
#   'определяться',
#   'индивидуально',
#   'итог',
#   'собеседование'],
#  ['обязанность',
#   'разработка',
#   'web',
#   'приложение',
#   'участие',
#   'обсуждение',
#   'проработка',
#   'концепция',
#   'новый',
#   'функционал',
#   'участие',
#   'построение',
#   'архитектура',
#   'проектирование',
#   'взаимодействие',
#   'стажёр',
#   'студент',
#   'алабуг',
#   'политех',
#   'требование',
#   'хороший',
#   'знание',
#   'python',
#   '3',
#   'опыт',
#   'работа',
#   'django',
#   'sanic',
#   'tornado',
#   'fastapi',
#   'опыт',
#   'работа',
#   'asyncio',
#   'опыт',
#   'работа',
#   'websocket',
#   'опыт',
#   'работа',
#   'pydantic',
#   'опыт',
#   'работа',
#   'docker',
#   'опыт',
#   'работа',
#   'git',
#   'уверенный',
#   'знание',
#   'rest',
#   'опыт',
#   'работа',
#   'реляционный',
#   'база',
#   'данные',
#   'postgresql',
#   'mysql',
#   'уровень',
#   'уверенный',
#   'middle',
#   'условие',
#   'дневный',
#   'рабочий',
#   'неделя',
#   '5',
#   '2',
#   '8',
#   '00',
#   '17',
#   '00',
#   'ненормированный',
#   'формат',
#   'работа',
#   'офис',
#   'работа',
#   'крупный',
#   'стабильный',
#   'компания',
#   'структура',
#   'большой',
#   'оэз',
#   'европа',
#   'транспорт',
#   'работа',
#   'г',
#   'елабуга',
#   'г',
#   'набережный',
#   'челны',
#   'г',
#   'менделеевск',
#   'оплачивать',
#   'отпуск',
#   'больничный',
#   'гарантия',
#   'профессиональный',
#   'рост',
#   'бесплатный',
#   'обучение',
#   'молодой',
#   'амбициозный',
#   'проектный',
#   'ориентировать',
#   'команда',
#   'командный',
#   'игра',
#   'мозговой',
#   'штурм',
#   'реализация',
#   'нестандартный',
#   'задача',
#   'карьерный',
#   'рост',
#   'наличие',
#   'обретение',
#   'процесс',
#   'работа',
#   'необходимый',
#   'компетенция',
#   'заработный',
#   'плата',
#   'результат',
#   'собеседование'],
#  ['проект',
#   'компания',
#   'amp',
#   'c',
#   'labs',
#   'итог',
#   'многолетний',
#   'деятельность',
#   'наш',
#   'команда',
#   'исследование',
#   'финансовый',
#   'рынок',
#   'исток',
#   'проект',
#   'широко',
#   'известный',
#   'узкий',
#   'круг',
#   'эксперт',
#   'торговый',
#   'стратегия',
#   'основатель',
#   'популярный',
#   'криптокомьюнити',
#   'архангел',
#   'бинанс',
#   'tpm',
#   'амазона',
#   'хороший',
#   'человек',
#   'разработать',
#   'принципиально',
#   'новый',
#   'автоматизированный',
#   'торговый',
#   'система',
#   'набирать',
#   'фулла',
#   'тайм',
#   'команда',
#   'доработка',
#   'обновление',
#   'продукт',
#   'требование',
#   'опыт',
#   'работа',
#   'роль',
#   'devops',
#   'engineer',
#   '2',
#   'год',
#   'опыт',
#   'работа',
#   'docker',
#   'docker',
#   'compose',
#   'docker',
#   'swarm',
#   'опыт',
#   'конфигурирование',
#   'управление',
#   'шардирование',
#   'postgresql',
#   'mongodb',
#   'mongo',
#   'atlas',
#   'знание',
#   'облачный',
#   'провайдер',
#   'aws',
#   'digital',
#   'ocean',
#   'настройка',
#   'подключение',
#   'load',
#   'balancer',
#   'инфраструктура',
#   'знание',
#   'linux',
#   'git',
#   'github',
#   'плюс',
#   'опыт',
#   'работа',
#   'celery',
#   'github',
#   'actions',
#   'grafana',
#   'prometheus',
#   'kubernetes',
#   'elk',
#   'условие',
#   'оформление',
#   'контракт',
#   'гибкий',
#   'график',
#   'полностью',
#   'удалённый',
#   'работа',
#   'отсутствие',
#   'бюрократия',
#   'сложный',
#   'долгий',
#   'согласование',
#   'возможность',
#   'предлагать',
#   'разрабатывать',
#   'внедрять',
#   'вместе',
#   'команда',
#   'собственный',
#   'технический',
#   'решение']]

# %%
path = '../storage/corpus_vacancies.pkl'

# with open(path, 'wb') as f:
#     pickle.dump(corpus, f)

# with open(path, 'rb') as f:
#     corpus = pickle.load(f)

# %%
import pickle
z = [1, 2 ,    3, 4, 5, [1, 2, 2, 1]]
with open('\\\\pns\\data\\a.pkl', 'rb') as f:
    # pickle.dump(z, f)
    print(pickle.load(f))
# Out:
# [1, 2, 3, 4, 5, [1, 2, 2, 1]]
